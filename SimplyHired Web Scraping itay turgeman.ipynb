# %% [markdown]
# Import the necessary libraries
# - To make a web page request
# - To save data to a dataframe
# - To interact with an SQL database
# - To parse web pages

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from sqlalchemy import create_engine

# %% [markdown]
# ### Web scrape a single web page and save the results to the simplyhired_job table

# %% [markdown]
# Set a variable to store the web page URL

# %%
page_url = 'https://www.simplyhired.com/search?q=sql&l=Los+Angeles%2C+CA&job=c0qDvt82XR-JgOFHDNoiJTqfmZuOqciYZbjC-zGGR_VnZ62ulqXC8w'

# %% [markdown]
# Set a dict of parameters to pass to the URL

# %%
params = {
    'q':'sql',
    'l':'Los Angeles'
}

# %% [markdown]
# Make a GET request with the defined URL and the dict of parameters

# %%
url_requ = requests.get(page_url,params)

# %% [markdown]
# Confirm the GET request received a 200 HTTP status code

# %%
url_requ
# Out:
# <Response [200]>

# %% [markdown]
# View the text in the GET request result

# %%
url_requ.text
# Out:
# '<!DOCTYPE html><html data-css="search" lang="en" ><head ga-id=UA-1039096-6><meta http-equiv="Content-Type" content="text/html; charset=utf-8" /><meta name="viewport" content="width=device-width, minimum-scale=1, initial-scale=1"><title>20 Best sql jobs in Los Angeles, CA (Hiring Now!) | SimplyHired</title><meta name="description" content="3,582 sql jobs available in Los Angeles, CA. See salaries, compare reviews, easily apply, and get hired. New sql careers in Los Angeles, CA are added daily on SimplyHired.com. The low-stress way to find your next sql job opportunity is on SimplyHired. There are over 3,582 sql careers in Los Angeles, CA waiting for you to apply!" /><meta name="keywords" content="sql jobs in Los Angeles, CA, job search engine, jobs, job listings, find jobs, careers, employment opportunity, online job sites, resumes, salaries, simple, hire" /><meta name="pageTk" content="1g0asvikuhbh8803" /><link rel="shortcut icon" type="image/x-icon" href="https://d3iouj7udfksni.cloudfront.net/favicon.ico" /><link rel="apple-touch-icon" href="/apple-touch-icon.png" /><link rel="canonical" href="https://www.simplyhired.com/search?q=sql&amp;l=los+angeles%2C+ca" /><meta name="g-client-id" content="939356510115-023sd5f62vape692qqdllhnoi4qmnv0c.apps.googleusercontent.com" /><meta name="f-client-id" content="225697117996081" /><meta name="f-redirect-url" content="https://www.simplyhired.com/auth/facebook/login" /><link rel="next" href="https://www.simplyhired.com/search?q=sql&amp;l=Los+Angeles%2C+CA&amp;pn=2&amp;from=pagination&amp;pp=gQALAAAAAAAAAAAAAAABz721mQAkAQEBBhqXgseCaVJu896uYOfVJGFaOE8rK%2BdBicfJfvbZDIsQAAA%3D" /><link rel=\'preload\' href=\'https://d3iouj7udfksni.cloudfront.net/packed/04702cff316c6225da748dbe163e9247.woff2\' as="font" type="font/woff2" crossorigin="anonymous"><link rel=\'preload\' href=\'https://d3iouj7udfksni.cloudfront.net/packed/5a85fc6d64c0e288776a7a569e47491f.woff2\' as="font" type="font/woff2" crossorigin="anonymous"><link rel=\'preload\' href=\'https://d3iouj7udfksni.cloudfront.net/packed/f207b673dbeeeebc971595ebec1a8989.woff2\' as="font" type="font/woff2" crossorigin="anonymous"><link rel=\'preload\' href=\'https://d3iouj7udfksni.cloudfront.net/packed/9d2c55331ff9c97b941b0b579da4b00a.woff2\' as="font" type="font/woff2" crossorigin="anonymous"><link rel=\'preload\' href=\'https://d3iouj7udfksni.cloudfront.net/packed/d824df7eb2e268626a2dd9a6a741ac4e.woff2\' as="font" type="font/woff2" crossorigin="anonymous"><link rel=\'preload\' href=\'https://d3iouj7udfksni.cloudfront.net/packed/b91d376b8d7646d671cd820950d5f7f1.woff2\' as="font" type="font/woff2" crossorigin="anonymous"><link rel="stylesheet" href="/packed/90a40516368058c6c1e1/search.css"/><script async src="/packed/8223238a3c4795d14290/main.js"></script><script src="https://d3fw5vlhllyvee.cloudfront.net/one-trust/dist/fa8b58b22d231ca04af9cd90997f2487/simplyhired/consent/e960f4af-3d87-423d-ae7c-514993d3c00a/OtAutoBlock.js" crossorigin="anonymous"></script><script defer data-domain-script="e960f4af-3d87-423d-ae7c-514993d3c00a" data-domain-name="simplyhired.com" data-language="en" src="https://d3fw5vlhllyvee.cloudfront.net/one-trust/dist/fa8b58b22d231ca04af9cd90997f2487/simplyhired/scripttemplates/otSDKStub.js" data-ignore-geolocation="true" crossorigin="anonymous"></script><template style=\'display:none;\' id=\'sentry-json\' data-json=\'{&quot;init&quot;:{&quot;dsn&quot;:&quot;https://f9dca67454f647c9ac710a500a0bbebb@sentry.indeed.com/2391&quot;,&quot;release&quot;:&quot;4fbf63f3db5041ebd56a07bed26b30174cc64830&quot;,&quot;environment&quot;:&quot;PRODUCTION&quot;},&quot;user&quot;:null,&quot;ctk&quot;:null,&quot;tags&quot;:{&quot;shk&quot;:&quot;1g0asvil1hbh8801&quot;,&quot;login&quot;:&quot;0&quot;,&quot;site&quot;:&quot;simplyhired&quot;,&quot;appinstance&quot;:&quot;CobraDaemon&quot;},&quot;extra&quot;:null,&quot;isEnabled&quot;:true,&quot;isEnabledLocally&quot;:true}\'></template><script src="/modernizr-webp.js"></script><meta name="tk" content= ...

# %% [markdown]
# Create an object of the BeautifulSoup class to parse the web page text with the html.parser parser option

# %%
new_page = BeautifulSoup(url_requ.text,'html.parser')

# %% [markdown]
# Print the BeautifulSoup object as a nicely (pretty) formatted string

# %%
print(new_page.prettify())
# Out:
# <!DOCTYPE html>
# <html data-css="search" lang="en">
#  <head ga-id="UA-1039096-6">
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <meta content="width=device-width, minimum-scale=1, initial-scale=1" name="viewport"/>
#   <title>
#    20 Best sql jobs in Los Angeles, CA (Hiring Now!) | SimplyHired
#   </title>
#   <meta content="3,582 sql jobs available in Los Angeles, CA. See salaries, compare reviews, easily apply, and get hired. New sql careers in Los Angeles, CA are added daily on SimplyHired.com. The low-stress way to find your next sql job opportunity is on SimplyHired. There are over 3,582 sql careers in Los Angeles, CA waiting for you to apply!" name="description">
#    <meta content="sql jobs in Los Angeles, CA, job search engine, jobs, job listings, find jobs, careers, employment opportunity, online job sites, resumes, salaries, simple, hire" name="keywords"/>
#    <meta content="1g0asvikuhbh8803" name="pageTk"/>
#    <link href="https://d3iouj7udfksni.cloudfront.net/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
#    <link href="/apple-touch-icon.png" rel="apple-touch-icon"/>
#    <link href="https://www.simplyhired.com/search?q=sql&amp;l=los+angeles%2C+ca" rel="canonical"/>
#    <meta content="939356510115-023sd5f62vape692qqdllhnoi4qmnv0c.apps.googleusercontent.com" name="g-client-id"/>
#    <meta content="225697117996081" name="f-client-id"/>
#    <meta content="https://www.simplyhired.com/auth/facebook/login" name="f-redirect-url"/>
#    <link href="https://www.simplyhired.com/search?q=sql&amp;l=Los+Angeles%2C+CA&amp;pn=2&amp;from=pagination&amp;pp=gQALAAAAAAAAAAAAAAABz721mQAkAQEBBhqXgseCaVJu896uYOfVJGFaOE8rK%2BdBicfJfvbZDIsQAAA%3D" rel="next"/>
#    <link as="font" crossorigin="anonymous" href="https://d3iouj7udfksni.cloudfront.net/packed/04702cff316c6225da748dbe163e9247.woff2" rel="preload" type="font/woff2"/>
#    <link as="font" crossorigin="anonymous" href="https://d3iouj7udfksni.cloudfront.net/packed/5a85fc6d64c0e288776a7a569e47491f.woff2" rel="preload" type="font/woff2"/>
#    <link as="font" crossorigin="anonymous" href="https://d3iouj7udfksni.cloudfront.net/packed/f207b673dbeeeebc971595ebec1a8989.woff2" rel="preload" type="font/woff2"/>
#    <link as="font" crossorigin="anonymous" href="https://d3iouj7udfksni.cloudfront.net/packed/9d2c55331ff9c97b941b0b579da4b00a.woff2" rel="preload" type="font/woff2"/>
#    <link as="font" crossorigin="anonymous" href="https://d3iouj7udfksni.cloudfront.net/packed/d824df7eb2e268626a2dd9a6a741ac4e.woff2" rel="preload" type="font/woff2"/>
#    <link as="font" crossorigin="anonymous" href="https://d3iouj7udfksni.cloudfront.net/packed/b91d376b8d7646d671cd820950d5f7f1.woff2" rel="preload" type="font/woff2"/>
#    <link href="/packed/90a40516368058c6c1e1/search.css" rel="stylesheet">
#     <script async="" src="/packed/8223238a3c4795d14290/main.js">
#     </script>
#     <script crossorigin="anonymous" src="https://d3fw5vlhllyvee.cloudfront.net/one-trust/dist/fa8b58b22d231ca04af9cd90997f2487/simplyhired/consent/e960f4af-3d87-423d-ae7c-514993d3c00a/OtAutoBlock.js">
#     </script>
#     <script crossorigin="anonymous" data-domain-name="simplyhired.com" data-domain-script="e960f4af-3d87-423d-ae7c-514993d3c00a" data-ignore-geolocation="true" data-language="en" defer="" src="https://d3fw5vlhllyvee.cloudfront.net/one-trust/dist/fa8b58b22d231ca04af9cd90997f2487/simplyhired/scripttemplates/otSDKStub.js">
#     </script>
#     <template data-json='{"init":{"dsn":"https://f9dca67454f647c9ac710a500a0bbebb@sentry.indeed.com/2391","release":"4fbf63f3db5041ebd56a07bed26b30174cc64830","environment":"PRODUCTION"},"user":null,"ctk":null,"tags":{"shk":"1g0asvil1hbh8801","login":"0","site":"simplyhired","appinstance":"CobraDaemon"},"extra":null,"isEnabled":true,"isEnabledLocally":true}' id="sentry-json" style="display:none;">
#     </template>
#     <script src="/modernizr-webp.js">
#     </script>
#     <meta content="1g0asvil5hbh8800" name="tk"/>
#    </link>
#   </meta>
#  </head>
#  <body class="search" data-csrf="I-eHIxSvKk5MYcp8D0XcguY-Nhh73iOUWBaUrZy1m8HiqrF-LPVSpT3geGYfT9nj_AkSV4079aJDRYsIi-x7pg" id="search">
#   <div class="GoogleOneTap-div" data-cancel_on_tap_outside="false" data-client_id="939356510115-023sd5f62vape692qqdllhnoi4qmnv0c.apps.googleusercontent.com" data-login_uri="/auth/google/login/onetap" id="g_id_onload">
#   </div>
#   <script async="" defer="" src="https://accounts.google.com/gsi/client">
#   </script>
#   <aside class="accessibility-links">
#    <a class="skip-link" href="#job-list">
#     Skip to content
#    </a>
#   </aside>
#   <div aria-labelledby="login-heading" aria-modal="true" class="modal fade modal-login" data-keyboard="true" id="main-login-modal" role="dialog">
#    <div class="modal-dialog">
#     <div class="modal-content">
#      <span id="login-modal-pre-focus-trap" tabindex="0">
#      </span>
#      <div class="modal-header">
#       <button aria-label="Close" class="close modal-dialog-first-focus" data-dismiss="modal" type="button">
#        <span aria-hidden="true">
#         ×
#        </span>
#       </button>
#       <h2 class="heading" id="login-heading">
#        Sign In or Create Account
#       </h2>
#      </div>
#      <div class="modal-body">
#       <p>
#        Use Facebook or Google to sign in or register with SimplyHired.
#       </p>
#       <div class="login-buttons">
#        <button class="btn btn-facebook js-login-facebook" type="button">
#         <span>
#          Continue with Facebook
#         </span>
#        </button>
#        <button class="btn btn-google js-login-google" type="button">
#         <span>
#          Continue with Google
#         </span>
#        </button>
#       </div>
#       <p class="login-disclaimer">
#        By signing in to your account, you agree to SimplyHired's
#        <a href="/about/terms-of-service">
#         Terms of Service
#        </a>
#        and consent to our
#        <a class="modal-dialog-last-focus" href="https://hrtechprivacy.com/brands/simplyhired#privacypolicy">
#         Cookie and Privacy Policy
#        </a>
#        .
#       </p>
#      </div>
#      <span id="login-modal-post-focus-trap" tabindex="0">
#      </span>
#     </div>
#    </div>
#   </div>
#   <div aria-hidden="true" class="modal fade modal-login modal-login-error" id="login-error-modal" role="dialog" tabindex="-1">
#    <div class="modal-content">
#     <div class="modal-header">
#      <button aria-label="Close" class="close" data-dismiss="modal" type="button">
#       <span>
#        ×
#       </span>
#      </button>
#      <h4 class="modal-title">
#       ERROR
#      </h4>
#     </div>
#     <div class="modal-body">
#     </div>
#    </div>
#   </div>
#   <div aria-hidden="true" class="modal fade modal-login modal-login-error" id="login-session-expired-modal" role="dialog" tabindex="-1">
#    <div class="modal-content">
#     <div class="modal-header">
#      <button aria-label="Close" class="close" data-dismiss="modal" type="button">
#       <span>
#        ×
#       </span>
#      </button>
#      <h4 class="modal-title">
#       ERROR
#      </h4>
#     </div>
#     <div class="modal-body">
#     </div>
#     <div class="modal-footer">
#      <div class="btn btn-secondary js-refresh">
#       <span>
#        Refresh the Page
#       </span>
#      </div>
#     </div>
#    </div>
#   </div>
#   <header>
#    <nav aria-label="Primary header" class="NavBar navbar navbar-light d-md-block d-none serp-navbar navbar-desktop top-menu NavBar-global-nav js-priority-nav">
#     <a aria-label="Find Jobs and Careers - SimplyHired.com Job Search" class="sh-logo-link" data-event="header_logo" data-nav-priority="0" data-testid="header-logo-SH" href="/">
#      <span class="sh-logo sh-logo-responsive">
#      </span>
#     </a>
#     <div class="NavBar-searchForm hidden-sm-down" data-nav-priority="0" data-nav-priority-wrap="1">
#      <div class="SearchForm-container" data-react-class="SearchForm" data-react-props='{"country":"us","jobTitleLabel":"Job Title","whatInputLabel":"Job Title, Skills or Company","query":"sql","language":"en","environment":"prod","whereInputLabel":"City, State, ZIP or \"Remote\"","searchButtonLabel":"Search Jobs","tk":"1g0asvil5hbh8800","location":"Los Angeles, CA","certificationLabel":"Certification","companyLabel":"Company","skillLabel":"Skill"}'>
#       <form action="/search" class="SearchForm" method="get">
#        <div class="SearchForm-textInput">
#         <div>
#          <div class="TextInput TextInput-field--hasValue">
#           <label class="TextInput-label" for="SearchForm-whatInput">
#            Job Title, Skills or Company
#           </label>
#           <input aria-autocomplete="list" aria-expanded="false" aria-label="Job Title, Skills or Company" aria-owns="SearchForm-whatInput-suggestion-list" autocomplete="off" class="TextInput-field" id="SearchForm-whatInput" name="q" role="combobox" type="text" value="sql"/>
#          </div>
#          <div class="autocomplete-container" style="z-index:2;position:relative;margin:0px;padding:0px">
#           <div id="SearchForm-whatInput-suggestion-list">
#           </div>
#          </div>
#         </div>
#        </div>
#        <div class="SearchForm-textInput">
#         <div>
#          <div class="TextInput TextInput-field--hasValue">
#           <label class="TextInput-label" for="SearchForm-whereInput">
#            City, State, ZIP or "Remote"
#           </label>
#           <input aria-autocomplete="list" aria-expanded="false" aria-label='City, State, ZIP or "Remote"' aria-owns="SearchForm-whereInput-suggestion-list" autocomplete="off" class="TextInput-field" id="SearchForm-whereInput" name="l" role="combobox" type="text" value="Los Angeles, CA"/>
#          </div>
#          <div class="autocomplete-container" style="z-index:2;position:relative;margin:0px;padding:0px">
#           <div id="SearchForm-whereInput-suggestion-list">
#           </div>
#          </div>
#         </div>
#        </div>
#        <span class="SearchForm-buttonContainer">
#         <button class="SearchForm-submitButton" type="submit">
#          Search Jobs
#         </button>
#        </span>
#       </form>
#      </div>
#     </div>
#     <div class="navbar-filler">
#     </div>
#     <ul class="nav navbar-nav" data-testid="header-navigation-signin-links">
#      <li class="nav-item hidden-md-down" data-nav-priority="4">
#       <a class="nav-link" href="/hr-tools?source=navbar">
#        <div class="nav-item-btn">
#         <i aria-hidden="true" class="fas fa-users nav-item-icon">
#         </i>
#         <span>
#          HR Tools
#         </span>
#        </div>
#       </a>
#      </li>
#      <li class="nav-item hidden-md-down" data-nav-priority="3">
#       <a class="nav-link" href="/post-jobs">
#        <div class="nav-item-btn">
#         <i aria-hidden="true" class="fas fa-briefcase nav-item-icon">
#         </i>
#         <span>
#          Post Jobs
#         </span>
#        </div>
#       </a>
#      </li>
#      <li class="nav-item login-desktop-nav-item" data-nav-priority="2">
#       <button class="nav-login-menu-button" type="button">
#        <span class="navbar-login-mobile-text">
#         Sign In / Sign Up
#        </span>
#        <span class="navbar-login-desktop-text">
#         Sign In / Create Account
#        </span>
#        <i class="button-toggle-angle fas fa-angle-down">
#        </i>
#       </button>
#       <ul class="nav-login-menu">
#        <li class="nav-login-menu-item">
#         <button aria-expanded="false" class="nav-login-menu-link" id="nav-login-modal-trigger">
#          Job Seeker
#         </button>
#        </li>
#        <li class="nav-login-menu-item">
#         <a class="nav-login-menu-link" href="https://employer.simplyhired.com" target="_self">
#          Post Jobs Login
#         </a>
#        </li>
#        <li class="nav-login-menu-item">
#         <a class="nav-login-menu-link" href="https://hr.simplyhired.com" target="_self">
#          HR Tools
#         </a>
#        </li>
#       </ul>
#      </li>
#      <li class="nav-item" data-nav-priority="0">
#       <button aria-controls="slideout-menu" aria-expanded="false" aria-label="Main menu" class="btn js-hamburger hamburger" data-toggle="collapse">
#        <i class="fas fa-bars">
#        </i>
#       </button>
#       <div class="slideout-menu-container">
#        <nav aria-hidden="true" aria-label="Main menu" class="slideout-menu js-menu" id="slideout-menu">
#         <span class="menu-catchFocusOut visuallyhidden" tabindex="0">
#          Top of menu
#         </span>
#         <div class="slideout-menu-content">
#          <div class="section-header search-section js-section-header">
#           <button aria-label="Close menu" class="btn close-icon js-close">
#           </button>
#          </div>
#          <div class="section-header js-section-header">
#           <button aria-controls="signin-dropdown-id" aria-expanded="false" class="btn section-toggle js-section-toggle" data-target=".js-signin" data-toggle="collapse" type="button">
#            Sign In / Create Account
#            <i class="section-toggle-angle fas fa-angle-down">
#            </i>
#           </button>
#          </div>
#          <div class="section-body js-section-body collapse js-signin" id="signin-dropdown-id" role="menu">
#           <ul>
#            <li>
#             <button class="btn section-option" id="mobile-login-modal-trigger">
#              Job Seeker
#             </button>
#            </li>
#            <li>
#             <a href="https://employer.simplyhired.com/">
#              Post Jobs Login
#             </a>
#            </li>
#            <li>
#             <a href="https://hr.simplyhired.com/">
#              HR Tools
#             </a>
#            </li>
#           </ul>
#          </div>
#          <div class="slideout-menu-divider js-search-divider">
#          </div>
#          <div class="section-header">
#           <span class="section-toggle">
#            <a href="/post-jobs">
#             Post Jobs Free
#            </a>
#           </span>
#          </div>
#          <div class="section-header">
#           <span class="section-toggle">
#            <a href="/hr-tools?source=hamburgermenu">
#             HR Tools
#            </a>
#           </span>
#          </div>
#          <div class="slideout-menu-divider js-search-divider">
#          </div>
#          <div class="section-header js-section-header">
#           <button aria-controls="browse-dropdown-id" aria-expanded="false" class="btn section-toggle js-section-toggle" data-target=".js-browse" data-toggle="collapse">
#            Browse
#            <i class="section-toggle-angle fas fa-angle-down">
#            </i>
#           </button>
#          </div>
#          <div aria-expanded="false" class="section-body js-section-body collapse js-browse" id="browse-dropdown-id" role="menu">
#           <ul>
#            <li>
#             <a href="/browse-jobs/companies">
#              All Companies
#             </a>
#            </li>
#            <li>
#             <a href="/browse-jobs/cities">
#              All Cities
#             </a>
#            </li>
#            <li>
#             <a href="/browse-jobs/titles">
#              All Jobs
#             </a>
#            </li>
#            <li>
#             <a href="/browse-jobs/salaries">
#              All Salaries
#             </a>
#            </li>
#           </ul>
#          </div>
#          <div class="section-header js-section-header">
#           <button aria-controls="nearbycities-dropdown-id" aria-expanded="false" class="btn section-toggle js-section-toggle" data-target=".js-nearbycities" data-toggle="collapse">
#            Nearby Cities
#            <i class="section-toggle-angle fas fa-angle-down">
#            </i>
#           </button>
#          </div>
#          <div aria-expanded="false" class="section-body js-section-body collapse js-nearbycities" id="nearbycities-dropdown-id" role="menu">
#           <ul>
#            <li>
#             <a href="/search?q=sql&amp;l=irvine%2C+ca&amp;pp=">
#              Jobs in Irvine, CA
#             </a>
#            </li>
#            <li>
#             <a href="/search?q=sql&amp;l=santa+monica%2C+ca&amp;pp=">
#              Jobs in Santa Monica, CA
#             </a>
#            </li>
#            <li>
#             <a href="/search?q=sql&amp;l=el+segundo%2C+ca&amp;pp=">
#              Jobs in El Segundo, CA
#             </a>
#            </li>
#            <li>
#             <a href="/search?q=sql&amp;l=costa+mesa%2C+ca&amp;pp=">
#              Jobs in Costa Mesa, CA
#             </a>
#            </li>
#            <li>
#             <a href="/search?q=sql&amp;l=long+beach%2C+ca&amp;pp=">
#              Jobs in Long Beach, CA
#             </a>
#            </li>
#           </ul>
#          </div>
#          <div class="section-header js-section-header">
#           <button aria-controls="companies-dropdown-id" aria-expanded="false" class="btn section-toggle js-section-toggle" data-target=".js-companies" data-toggle="collapse">
#            Suggested Companies
#            <i class="section-toggle-angle fas fa-angle-down">
#            </i>
#           </button>
#          </div>
#          <div aria-expanded="false" class="section-body js-section-body collapse js-companies" id="companies-dropdown-id" role="menu">
#           <ul>
#            <li>
#             <a href="/search?q=deloitte&amp;l=los+angeles%2C+ca&amp;pp=">
#              Deloitte
#             </a>
#            </li>
#            <li>
#             <a href="/search?q=amazon.com+services+llc&amp;l=los+angeles%2C+ca&amp;pp=">
#              Amazon.com Services LLC
#             </a>
#            </li>
#            <li>
#             <a href="/search?q=price+waterhouse+coopers&amp;l=los+angeles%2C+ca&amp;pp=">
#              PRICE WATERHOUSE COOPERS
#             </a>
#            </li>
#            <li>
#             <a href="/search?q=recruiting+from+scratch&amp;l=los+angeles%2C+ca&amp;pp=">
#              Recruiting From Scratch
#             </a>
#            </li>
#            <li>
#             <a href="/search?q=kpmg&amp;l=los+angeles%2C+ca&amp;pp=">
#              KPMG
#             </a>
#            </li>
#           </ul>
#          </div>
#          <div class="section-header NavBar-sectionResumeBuilder">
#           <span class="section-toggle">
#            <a href="/resumebuilder" target="_blank">
#             Resume Builder
#            </a>
#           </span>
#          </div>
#          <div class="section-header">
#           <span class="section-toggle">
#            <a href="/company">
#             Company Pages
#            </a>
#           </span>
#          </div>
#          <div class="section-header js-section-header" data-testid="menu-tools-dropdown">
#           <button aria-controls="job-tools-dropdown-id" aria-expanded="false" class="btn section-toggle js-section-toggle" data-target=".js-jobseekers" data-toggle="collapse">
#            Job Tools
#            <i class="section-toggle-angle fas fa-angle-down">
#            </i>
#           </button>
#          </div>
#          <div aria-expanded="false" class="section-body js-section-body collapse js-jobseekers" id="job-tools-dropdown-id" role="menu">
#           <ul>
#            <li>
#             <a class="local" href="/local-jobs">
#              Local Jobs
#             </a>
#            </li>
#            <li>
#             <a class="salary" href="/salaries">
#              Salary Estimator
#             </a>
#            </li>
#            <li>
#             <a class="career" href="/search/advice">
#              Career Advice Home
#             </a>
#            </li>
#            <li>
#             <a class="resumes" href="/search/advice/resume-samples">
#              Sample Resumes
#             </a>
#            </li>
#            <li>
#             <a class="interview" href="/search/advice/interview-questions">
#              Sample Interview Questions
#             </a>
#            </li>
#            <li>
#             <a class="job-description" href="/post-jobs/job-descriptions">
#              Job Descriptions
#             </a>
#            </li>
#           </ul>
#          </div>
#          <div class="section-header">
#           <span class="section-toggle">
#            <a href="/about/contact-us" rel="nofollow" target="_self">
#             Contact Us
#            </a>
#           </span>
#          </div>
#          <div class="menu-footer">
#           <div class="copyright">
#            <span class="sh-logo">
#            </span>
#            <br/>
#            <div class="dropup international-dropdown international-dropdown-v2">
#             <button aria-expanded="false" aria-haspopup="true" aria-label="Country selector: United States, select to change your country" class="international-dropdown-button-v2" data-testid="country-selector-SH" data-toggle="dropdown" type="button">
#              <span>
#               United States
#              </span>
#              <span class="dropdown-arrow-container">
#               <i class="fas fa-angle-down">
#               </i>
#              </span>
#             </button>
#             <div class="dropdown-menu international-dropdown-wrapper" data-testid="country-selector-dropdown-SH">
#              <div class="international-dropdown-list">
#               <a class="current-country dropdown-item" href="https://www.simplyhired.com" rel="nofollow">
#                United States
#               </a>
#               <a class="dropdown-item" href="https://www.simplyhired.ca" rel="nofollow">
#                Canada
#               </a>
#               <div class="dropdown-divider">
#               </div>
#               <a class="dropdown-item" href="https://www.simplyhired.com.ar" rel="nofollow">
#                Argentina
#               </a>
#               <a class="dropdown-item" href="https://www.simplyhired.com.au" rel="nofollow">
#                Australia
#               </a>
#               <a class="dropdown-item" href="https://www.simplyhired.be" rel="nofollow">
#                België
#               </a>
#               <a class="dropdown-item" href="https://www.simplyhired.com.br" rel="nofollow">
#                Brasil
#               </a>
#               <a class="dropdown-item" href="https://www.simplyhired.de" rel="nofollow">
#                Deutschland
#               </a>
#               <a class="dropdown-item" href="https://www.simplyhired.es" rel="nofollow">
#                España
#               </a>
#               <a class="dropdown-item" href="https://www.simplyhired.fr" rel="nofollow">
#                France
#               </a>
#               <a class="dropdown-item" href="https://www.simplyhired.co.in" rel="nofollow">
#                India
#               </a>
#               <a class="dropdown-item" href="https://www.simplyhired.ie" rel="nofollow">
#                Ireland
#               </a>
#               <a class="dropdown-item" href="https://www.simplyhired.it" rel="nofollow">
#                Italia
#               </a>
#               <a class="dropdown-item" href="https://www.simplyhired.mx" rel="nofollow">
#                México
#               </a>
#               <a class="dropdown-item" href="https://www.simplyhired.nl" rel="nofollow">
#                Nederland
#               </a>
#               <a class="dropdown-item" href="https://www.simplyhired.at" rel="nofollow">
#                Österreich
#               </a>
#               <a class="dropdown-item" href="https://www.simplyhired.pt" rel="nofollow">
#                Portugal
#               </a>
#               <a class="dropdown-item" href="https://www.simplyhired.ch" rel="nofollow">
#                Schweiz
#               </a>
#               <a class="dropdown-item" href="https://za.simplyhired.com" rel="nofollow">
#                South Africa
#               </a>
#               <a class="dropdown-item" href="https://www.simplyhired.se" rel="nofollow">
#                Sverige
#               </a>
#               <a class="dropdown-item" href="https://www.simplyhired.co.uk" rel="nofollow">
#                United Kingdom
#               </a>
#               <a class="dropdown-item" href="https://www.simplyhired.kr" rel="nofollow">
#                한국
#               </a>
#               <a class="dropdown-item" href="https://www.simplyhired.cn" rel="nofollow">
#                中国
#               </a>
#               <a class="dropdown-item" href="https://www.simplyhired.jp" rel="nofollow">
#                日本
#               </a>
#              </div>
#             </div>
#            </div>
#            <div class="misc-links text-xs-left">
#             © 2022 SH Inc. |
#             <a href="https://hrtechprivacy.com/brands/simplyhired#privacypolicy">
#              Privacy
#             </a>
#             |
#             <a href="/about/terms-of-service">
#              Terms
#             </a>
#             <br/>
#             |
#             <a href="https://hrtechprivacy.com/">
#              Privacy Center
#             </a>
#             |
#             <a href="/accessibility">
#              Accessibility
#             </a>
#             <br/>
#             |
#             <a href="/about/ccpa">
#              Do Not Sell My Personal Information
#             </a>
#            </div>
#           </div>
#          </div>
#         </div>
#         <span class="menu-catchFocusOut visuallyhidden" tabindex="0">
#          Bottom of menu
#         </span>
#        </nav>
#       </div>
#      </li>
#     </ul>
#    </nav>
#   </header>
#   <div class="mobile-container hidden-md-up">
#    <div class="SearchForm-container" data-react-class="SearchForm" data-react-props='{"country":"us","jobTitleLabel":"Job Title","whatInputLabel":"Job Title, Skills or Company","query":"sql","language":"en","searchFormCollapserLabel":"Currently showing sql jobs near Los Angeles, CA. Click to change search fields.","environment":"prod","disableFloatingLabel":true,"cancelButtonLabel":"Cancel","whereInputLabel":"City, State, ZIP or \"Remote\"","searchButtonLabel":"Search Jobs","collapsable":true,"tk":"1g0asvil5hbh8800","formattedWhatWhere":"sql jobs near Los Angeles, CA","action":"/search","location":"Los Angeles, CA","certificationLabel":"Certification","companyLabel":"Company","skillLabel":"Skill"}'>
#     <form action="/search" class="SearchForm" method="get">
#      <div class="SearchForm-searchControls mobile-search-controls hidden-md-up">
#       <h1 class="js-search-name">
#        <button aria-controls="mobile-search-collapser" aria-label="Currently showing sql jobs near Los Angeles, CA. Click to change search fields." class="js-search-trigger search-trigger collapsed" data-target="#mobile-search-collapser" data-toggle="collapse" type="button">
#         sql jobs near Los Angeles, CA
#        </button>
#       </h1>
#      </div>
#      <div aria-expanded="false" class="SearchForm-collapser collapse" id="mobile-search-collapser" role="menu">
#       <div class="SearchForm-textInput">
#        <div>
#         <div class="TextInput">
#          <label class="TextInput-label TextInput-label--static" for="SearchForm-whatInput-mobile">
#           Job Title, Skills or Company
#          </label>
#          <input aria-autocomplete="list" aria-expanded="false" aria-label="Job Title, Skills or Company" aria-owns="SearchForm-whatInput-mobile-suggestion-list" autocomplete="off" class="TextInput-field" id="SearchForm-whatInput-mobile" name="q" role="combobox" type="text" value="sql"/>
#         </div>
#         <div class="autocomplete-container" style="z-index:2;position:relative;margin:0px;padding:0px">
#          <div id="SearchForm-whatInput-mobile-suggestion-list">
#          </div>
#         </div>
#        </div>
#       </div>
#       <div class="SearchForm-textInput">
#        <div>
#         <div class="TextInput">
#          <label class="TextInput-label TextInput-label--static" for="SearchForm-whereInput-mobile">
#           City, State, ZIP or "Remote"
#          </label>
#          <input aria-autocomplete="list" aria-expanded="false" aria-label='City, State, ZIP or "Remote"' aria-owns="SearchForm-whereInput-mobile-suggestion-list" autocomplete="off" class="TextInput-field" id="SearchForm-whereInput-mobile" name="l" role="combobox" type="text" value="Los Angeles, CA"/>
#         </div>
#         <div class="autocomplete-container" style="z-index:2;position:relative;margin:0px;padding:0px">
#          <div id="SearchForm-whereInput-mobile-suggestion-list">
#          </div>
#         </div>
#        </div>
#       </div>
#       <span class="SearchForm-buttonContainer">
#        <button aria-controls="mobile-search-collapser" class="SearchForm-cancelButton collapsed" data-target="#mobile-search-collapser" data-toggle="collapse" type="button">
#         Cancel
#        </button>
#        <button class="SearchForm-submitButton" type="submit">
#         Search Jobs
#        </button>
#       </span>
#      </div>
#     </form>
#    </div>
#   </div>
#   <main class="content" id="content">
#    <div>
#     <div class="posting-headline clearfix">
#      <div class="hidden-md-up">
#       <div class="MobileHeadline">
#        <div class="MobileHeadline-mapViewToggle">
#         <a class="MapViewSwitchToggle" href="/search/map?q=sql&amp;l=los+angeles%2C+ca&amp;pp=">
#          <div class="MapViewSwitchToggle-toggle MapViewSwitchToggle-toggle--active">
#           List View
#          </div>
#          <div class="MapViewSwitchToggle-toggle">
#           Show Map
#          </div>
#         </a>
#        </div>
#        <div class="mobile-headline MobileHeadline-mobileFilters collapsed" data-target="#mobile-filters-collapser" data-toggle="collapse" style="cursor: pointer">
#         <button class="btn-mobile-filter" data-testid="filter-menu-button">
#          Sort &amp; Filter
#          <i aria-hidden="true" class="fas fa-angle-down fa-fw">
#          </i>
#         </button>
#        </div>
#       </div>
#      </div>
#      <div class="hidden-sm-down">
#       <section aria-label="Filters and saved jobs" class="jobposting-subNavigation wrap">
#        <div data-react-class="Filters" data-react-props='{"savedJobs":{"link":null,"label":"Saved Jobs"},"translations":"{}","filters":[{"filterData":{"current":{"link":"/search?q=sql&amp;l=los+angeles%2C+ca&amp;from=serptopfilter&amp;pp=","name":"Relevance","value":null,"count":0},"options":[{"link":"/search?q=sql&amp;l=los+angeles%2C+ca&amp;from=serptopfilter&amp;pp=","name":"Relevance","value":null,"count":0},{"link":"/search?q=sql&amp;l=los+angeles%2C+ca&amp;sb=dd&amp;from=serptopfilter&amp;pp=","name":"Date","value":null,"count":0}],"isDefault":true,"id":null,"title":null,"forceShowAll":false},"id":"SortBy","title":"Sort by"},{"filterData":{"current":{"link":"/search?q=sql&amp;l=los+angeles%2C+ca&amp;from=serptopfilter&amp;pp=","name":"25 miles","value":null,"count":0},"options":[{"link":"/search?q=sql&amp;l=los+angeles%2C+ca&amp;mi=exact&amp;from=serptopfilter&amp;pp=","name":"Exact location","value":null,"count":0},{"link":"/search?q=sql&amp;l=los+angeles%2C+ca&amp;mi=5&amp;from=serptopfilter&amp;pp=","name":"5 miles","value":null,"count":0},{"link":"/search?q=sql&amp;l=los+angeles%2C+ca&amp;mi=10&amp;from=serptopfilter&amp;pp=","name":"10 miles","value":null,"count":0},{"link":"/search?q=sql&amp;l=los+angeles%2C+ca&amp;mi=15&amp;from=serptopfilter&amp;pp=","name":"15 miles","value":null,"count":0},{"link":"/search?q=sql&amp;l=los+angeles%2C+ca&amp;from=serptopfilter&amp;pp=","name":"25 miles","value":null,"count":0},{"link":"/search?q=sql&amp;l=los+angeles%2C+ca&amp;mi=50&amp;from=serptopfilter&amp;pp=","name":"50 miles","value":null,"count":0},{"link":"/search?q=sql&amp;l=los+angeles%2C+ca&amp;mi=100&amp;from=serptopfilter&amp;pp=","name":"100 miles","value":null,"count":0}],"isDefault":true,"id":null,"title":null,"forceShowAll":false},"id":"Distance","title":"Distance"},{"filterData":{"current":{"link":"/search?q=sql&amp;l=los+angeles%2C+ca&amp;from=serptopfilter&amp;pp=","name":"All Job Types","value":null,"count":0},"options":[{"link":"/search?q=sql&amp;l=los+angeles%2C+ca&amp;from=serptopfilter&amp;pp=","name":"All Job Types","value":null,"count":0},{"link":"/search?q=sql&amp;l=los+angeles%2C+ca&amp;from=serptopfilter&amp;jt=fulltime&amp;pp=","name":"Full-time","value":null,"count":0},{"link":"/search?q=sql&amp;l=los+angeles%2C+ca&amp;from=serptopfilter&amp;jt=contract&amp;pp=","name":"Contract","value":null,"count":0},{"link":"/search?q=sql&amp;l=los+angeles%2C+ca&amp;from=serptopfilter&amp;jt=parttime&amp;pp=","name":"Part-time","value":null,"count":0},{"link":"/search?q=sql&amp;l=los+angeles%2C+ca&amp;from=serptopfilter&amp;jt=temporary&amp;pp=","name":"Temporary","value":null,"count":0},{"link":"/search?q=sql&amp;l=los+angeles%2C+ca&amp;from=serptopfilter&amp;jt=internship&amp;pp=","name":"Internship","value":null,"count":0}],"isDefault":true,"id":null,"title":null,"forceShowAll":false},"id":"JobType","title":"Job Type"},{"filterData":{"current":{"link":"/search?q=sql&amp;l=los+angeles%2C+ca&amp;from=serptopfilter&amp;pp=","name":"All Salaries","value":null,"count":0},"options":[{"link":"/search?q=sql&amp;l=los+angeles%2C+ca&amp;from=serptopfilter&amp;pp=","name":"All Salaries","value":null,"count":0},{"link":"/search?q=sql&amp;l=los+angeles%2C+ca&amp;mip=%2470%2C000&amp;from=serptopfilter&amp;pp=","name":"$70,000","value":null,"count":0},{"link":"/search?q=sql&amp;l=los+angeles%2C+ca&amp;mip=%2490%2C000&amp;from=serptopfilter&amp;pp=","name":"$90,000","value":null,"count":0},{"link":"/search?q=sql&amp;l=los+angeles%2C+ca&amp;mip=%24105%2C000&amp;from=serptopfilter&amp;pp=","name":"$105,000","value":null,"count":0},{"link":"/search?q=sql&amp;l=los+angeles%2C+ca&amp;mip=%24120%2C000&amp;from=serptopfilter&amp;pp=","name":"$120,000","value":null,"count":0},{"link":"/search?q=sql&amp;l=los+angeles%2C+ca&amp;mip=%24140%2C000&amp;from=serptopfilter&amp;pp=","name":"$140,000","value":null,"count":0}],"isDefault":true,"id":null,"title":null,"forceShowAll":false},"id":"MinimumPay","title":"Minimum Salary"},{"filterDat ...
#         <div class="Filters">
#          <a aria-label="Currently sorting results by Relevance. Click to sort by Date" class="SortToggle" href="/search?q=sql&amp;l=los+angeles%2C+ca&amp;sb=dd&amp;from=serptopfilter&amp;pp=">
#           <span class="SortToggle-sortOption active">
#            Relevance
#           </span>
#           <span class="SortToggle-sortOption">
#            Date
#           </span>
#          </a>
#          <div class="Filters-dropdown" data-id="Distance" data-testid="Distance">
#           <button aria-controls="Filters-dropdownBody-Distance" aria-expanded="false" aria-label="Distance Filter" class="Filters-dropdownHeader">
#            Distance
#            <i class="fas fa-angle-down">
#            </i>
#           </button>
#           <div class="Filters-dropdownBody" id="Filters-dropdownBody-Distance">
#            <a class="Filters-dropdownOption" href="/search?q=sql&amp;l=los+angeles%2C+ca&amp;mi=exact&amp;from=serptopfilter&amp;pp=">
#             Exact location
#            </a>
#            <a class="Filters-dropdownOption" href="/search?q=sql&amp;l=los+angeles%2C+ca&amp;mi=5&amp;from=serptopfilter&amp;pp=">
#             5 miles
#            </a>
#            <a class="Filters-dropdownOption" href="/search?q=sql&amp;l=los+angeles%2C+ca&amp;mi=10&amp;from=serptopfilter&amp;pp=">
#             10 miles
#            </a>
#            <a class="Filters-dropdownOption" href="/search?q=sql&amp;l=los+angeles%2C+ca&amp;mi=15&amp;from=serptopfilter&amp;pp=">
#             15 miles
#            </a>
#            <a class="Filters-dropdownOption active" href="/search?q=sql&amp;l=los+angeles%2C+ca&amp;from=serptopfilter&amp;pp=">
#             25 miles
#            </a>
#            <a class="Filters-dropdownOption" href="/search?q=sql&amp;l=los+angeles%2C+ca&amp;mi=50&amp;from=serptopfilter&amp;pp=">
#             50 miles
#            </a>
#            <a class="Filters-dropdownOption" href="/search?q=sql&amp;l=los+angeles%2C+ca&amp;mi=100&amp;from=serptopfilter&amp;pp=">
#             100 miles
#            </a>
#           </div>
#          </div>
#          <div class="Filters-dropdown" data-id="JobType" data-testid="JobType">
#           <button aria-controls="Filters-dropdownBody-JobType" aria-expanded="false" aria-label="Job Type Filter" class="Filters-dropdownHeader">
#            Job Type
#            <i class="fas fa-angle-down">
#            </i>
#           </button>
#           <div class="Filters-dropdownBody" id="Filters-dropdownBody-JobType">
#            <a class="Filters-dropdownOption active" href="/search?q=sql&amp;l=los+angeles%2C+ca&amp;from=serptopfilter&amp;pp=">
#             All Job Types
#            </a>
#            <a class="Filters-dropdownOption" href="/search?q=sql&amp;l=los+angeles%2C+ca&amp;from=serptopfilter&amp;jt=fulltime&amp;pp=">
#             Full-time
#            </a>
#            <a class="Filters-dropdownOption" href="/search?q=sql&amp;l=los+angeles%2C+ca&amp;from=serptopfilter&amp;jt=contract&amp;pp=">
#             Contract
#            </a>
#            <a class="Filters-dropdownOption" href="/search?q=sql&amp;l=los+angeles%2C+ca&amp;from=serptopfilter&amp;jt=parttime&amp;pp=">
#             Part-time
#            </a>
#            <a class="Filters-dropdownOption" href="/search?q=sql&amp;l=los+angeles%2C+ca&amp;from=serptopfilter&amp;jt=temporary&amp;pp=">
#             Temporary
#            </a>
#            <a class="Filters-dropdownOption" href="/search?q=sql&amp;l=los+angeles%2C+ca&amp;from=serptopfilter&amp;jt=internship&amp;pp=">
#             Internship
#            </a>
#           </div>
#          </div>
#          <div class="Filters-dropdown" data-id="MinimumPay" data-testid="MinimumPay">
#           <button aria-controls="Filters-dropdownBody-MinimumPay" aria-expanded="false" aria-label="Minimum Salary Filter" class="Filters-dropdownHeader">
#            Minimum Salary
#            <i class="fas fa-angle-down">
#            </i>
#           </button>
#           <div class="Filters-dropdownBody" id="Filters-dropdownBody-MinimumPay">
#            <a class="Filters-dropdownOption active" href="/search?q=sql&amp;l=los+angeles%2C+ca&amp;from=serptopfilter&amp;pp=">
#             All Salaries
#            </a>
#            <a class="Filters-dropdownOption" href="/search?q=sql&amp;l=los+angeles%2C+ca&amp;mip=%2470%2C000&amp;from=serptopfilter&amp;pp=">
#             $70,000
#            </a>
#            <a class="Filters-dropdownOption" href="/search?q=sql&amp;l=los+angeles%2C+ca&amp;mip=%2490%2C000&amp;from=serptopfilter&amp;pp=">
#             $90,000
#            </a>
#            <a class="Filters-dropdownOption" href="/search?q=sql&amp;l=los+angeles%2C+ca&amp;mip=%24105%2C000&amp;from=serptopfilter&amp;pp=">
#             $105,000
#            </a>
#            <a class="Filters-dropdownOption" href="/search?q=sql&amp;l=los+angeles%2C+ca&amp;mip=%24120%2C000&amp;from=serptopfilter&amp;pp=">
#             $120,000
#            </a>
#            <a class="Filters-dropdownOption" href="/search?q=sql&amp;l=los+angeles%2C+ca&amp;mip=%24140%2C000&amp;from=serptopfilter&amp;pp=">
#             $140,000
#            </a>
#           </div>
#          </div>
#          <div class="Filters-dropdown" data-id="Date" data-testid="Date">
#           <button aria-controls="Filters-dropdownBody-Date" aria-expanded="false" aria-label="Date Added Filter" class="Filters-dropdownHeader">
#            Date Added
#            <i class="fas fa-angle-down">
#            </i>
#           </button>
#           <div class="Filters-dropdownBody" id="Filters-dropdownBody-Date">
#            <a class="Filters-dropdownOption active" href="/search?q=sql&amp;l=los+angeles%2C+ca&amp;from=serptopfilter&amp;pp=">
#             Anytime
#            </a>
#            <a class="Filters-dropdownOption" href="/search?q=sql&amp;l=los+angeles%2C+ca&amp;fdb=1&amp;from=serptopfilter&amp;pp=">
#             24 hours
#            </a>
#            <a class="Filters-dropdownOption" href="/search?q=sql&amp;l=los+angeles%2C+ca&amp;fdb=7&amp;from=serptopfilter&amp;pp=">
#             7 days
#            </a>
#            <a class="Filters-dropdownOption" href="/search?q=sql&amp;l=los+angeles%2C+ca&amp;fdb=14&amp;from=serptopfilter&amp;pp=">
#             14 days
#            </a>
#            <a class="Filters-dropdownOption" href="/search?q=sql&amp;l=los+angeles%2C+ca&amp;fdb=30&amp;from=serptopfilter&amp;pp=">
#             30 days
#            </a>
#           </div>
#          </div>
#          <span class="Filters-wrapBreak">
#          </span>
#         </div>
#        </div>
#        <div class="jobposting-h1">
#         <span class="posting-total">
#          3,582
#         </span>
#         <h1>
#          sql jobs near Los Angeles, CA
#         </h1>
#         <button aria-expanded="false" aria-haspopup="true" aria-label="Sponsored jobs disclaimer" class="SponsoredJobsDisclaimer" data-toggle="popover" tabindex="0">
#          <i class="far fa-question-circle">
#          </i>
#         </button>
#         <div class="SponsoredJobsDisclaimer-popover" tabindex="-1">
#          <p class="SponsoredJobsDisclaimer-content">
#           Displayed here are Job Ads that match your query. SimplyHired may be compensated by these employers, helping keep SimplyHired free for jobseekers. SimplyHired ranks Job Ads based on a combination of employer bids and relevance, such as your search terms and other activity on SimplyHired. For more information, see the
#           <a class="SponsoredJobsDisclaimer-link" href="https://hrtechprivacy.com/brands/simplyhired#privacypolicy" target="_blank">
#            SimplyHired Privacy Policy
#           </a>
#           .
#          </p>
#         </div>
#        </div>
#       </section>
#      </div>
#     </div>
#     <div class="collapse hidden-md-up" id="mobile-filters-collapser">
#      <div class="MobileFilters">
#       <p class="MobileFilters-head">
#        Refine Your Search
#       </p>
#       <div class="MobileFilters-options">
#        <div class="MobileFilters-group MobileFilters-group-jobtype" data-testid="jobtype-filter-group">
#         <p class="MobileFilters-label fl-jobtype" id="MobJobType">
#          Job Type
#         </p>
#         <ul aria-labelledby="MobJobType" class="MobileFilters-list js-filter-menu">
#          <li class="MobileFilters-listItem">
#           <a class="MobileFilters-listItemLink active" data-iscurrent="true" data-testid="filter-button" href="/search?q=sql&amp;l=los+angeles%2C+ca&amp;from=serptopfilter&amp;pp=" rel="nofollow">
#            All Job Types
#           </a>
#          </li>
#          <li class="MobileFilters-listItem">
#           <a class="MobileFilters-listItemLink" data-testid="filter-button" href="/search?q=sql&amp;l=los+angeles%2C+ca&amp;from=serptopfilter&amp;jt=fulltime&amp;pp=" rel="nofollow">
#            Full-time
#           </a>
#          </li>
#          <li class="MobileFilters-listItem">
#           <a class="MobileFilters-listItemLink" data-testid="filter-button" href="/search?q=sql&amp;l=los+angeles%2C+ca&amp;from=serptopfilter&amp;jt=contract&amp;pp=" rel="nofollow">
#            Contract
#           </a>
#          </li>
#          <li class="MobileFilters-listItem">
#           <a class="MobileFilters-listItemLink" data-testid="filter-button" href="/search?q=sql&amp;l=los+angeles%2C+ca&amp;from=serptopfilter&amp;jt=parttime&amp;pp=" rel="nofollow">
#            Part-time
#           </a>
#          </li>
#          <li class="MobileFilters-listItem">
#           <a class="MobileFilters-listItemLink" data-testid="filter-button" href="/search?q=sql&amp;l=los+angeles%2C+ca&amp;from=serptopfilter&amp;jt=temporary&amp;pp=" rel="nofollow">
#            Temporary
#           </a>
#          </li>
#          <li class="MobileFilters-listItem">
#           <a class="MobileFilters-listItemLink" data-testid="filter-button" href="/search?q=sql&amp;l=los+angeles%2C+ca&amp;from=serptopfilter&amp;jt=internship&amp;pp=" rel="nofollow">
#            Internship
#           </a>
#          </li>
#         </ul>
#        </div>
#        <div class="MobileFilters-group MobileFilters-group-minimumpay" data-testid="minimumpay-filter-group">
#         <p class="MobileFilters-label fl-minimumpay" id="MobMinimumPay">
#          Minimum Salary
#         </p>
#         <ul aria-labelledby="MobMinimumPay" class="MobileFilters-list js-filter-menu">
#          <li class="MobileFilters-listItem">
#           <a class="MobileFilters-listItemLink active" data-iscurrent="true" data-testid="filter-button" href="/search?q=sql&amp;l=los+angeles%2C+ca&amp;from=serptopfilter&amp;pp=" rel="nofollow">
#            All Salaries
#           </a>
#          </li>
#          <li class="MobileFilters-listItem">
#           <a class="MobileFilters-listItemLink" data-testid="filter-button" href="/search?q=sql&amp;l=los+angeles%2C+ca&amp;mip=%2470%2C000&amp;from=serptopfilter&amp;pp=" rel="nofollow">
#            $70,000
#           </a>
#          </li>
#          <li class="MobileFilters-listItem">
#           <a class="MobileFilters-listItemLink" data-testid="filter-button" href="/search?q=sql&amp;l=los+angeles%2C+ca&amp;mip=%2490%2C000&amp;from=serptopfilter&amp;pp=" rel="nofollow">
#            $90,000
#           </a>
#          </li>
#          <li class="MobileFilters-listItem">
#           <a class="MobileFilters-listItemLink" data-testid="filter-button" href="/search?q=sql&amp;l=los+angeles%2C+ca&amp;mip=%24105%2C000&amp;from=serptopfilter&amp;pp=" rel="nofollow">
#            $105,000
#           </a>
#          </li>
#          <li class="MobileFilters-listItem">
#           <a class="MobileFilters-listItemLink" data-testid="filter-button" href="/search?q=sql&amp;l=los+angeles%2C+ca&amp;mip=%24120%2C000&amp;from=serptopfilter&amp;pp=" rel="nofollow">
#            $120,000
#           </a>
#          </li>
#          <li class="MobileFilters-listItem">
#           <a class="MobileFilters-listItemLink" data-testid="filter-button" href="/search?q=sql&amp;l=los+angeles%2C+ca&amp;mip=%24140%2C000&amp;from=serptopfilter&amp;pp=" rel="nofollow">
#            $140,000
#           </a>
#          </li>
#         </ul>
#        </div>
#        <div class="MobileFilters-group MobileFilters-group-sort" data-testid="sort-filter-group">
#         <p class="MobileFilters-label fl-sort" id="MobSortBy">
#          Sort by
#         </p>
#         <ul aria-labelledby="MobSortBy" class="MobileFilters-list js-filter-menu">
#          <li class="MobileFilters-listItem">
#           <a class="MobileFilters-listItemLink active" data-iscurrent="true" data-testid="filter-button" href="/search?q=sql&amp;l=los+angeles%2C+ca&amp;from=serptopfilter&amp;pp=" rel="nofollow">
#            Relevance
#           </a>
#          </li>
#          <li class="MobileFilters-listItem">
#           <a class="MobileFilters-listItemLink" data-testid="filter-button" href="/search?q=sql&amp;l=los+angeles%2C+ca&amp;sb=dd&amp;from=serptopfilter&amp;pp=" rel="nofollow">
#            Date
#           </a>
#          </li>
#         </ul>
#        </div>
#        <div class="MobileFilters-group MobileFilters-group-date" data-testid="date-filter-group">
#         <p class="MobileFilters-label fl-date" id="MobDate">
#          Date Added
#         </p>
#         <ul aria-labelledby="MobDate" class="MobileFilters-list js-filter-menu">
#          <li class="MobileFilters-listItem">
#           <a class="MobileFilters-listItemLink active" data-iscurrent="true" data-testid="filter-button" href="/search?q=sql&amp;l=los+angeles%2C+ca&amp;from=serptopfilter&amp;pp=" rel="nofollow">
#            Anytime
#           </a>
#          </li>
#          <li class="MobileFilters-listItem">
#           <a class="MobileFilters-listItemLink" data-testid="filter-button" href="/search?q=sql&amp;l=los+angeles%2C+ca&amp;fdb=1&amp;from=serptopfilter&amp;pp=" rel="nofollow">
#            24 hours
#           </a>
#          </li>
#          <li class="MobileFilters-listItem">
#           <a class="MobileFilters-listItemLink" data-testid="filter-button" href="/search?q=sql&amp;l=los+angeles%2C+ca&amp;fdb=7&amp;from=serptopfilter&amp;pp=" rel="nofollow">
#            7 days
#           </a>
#          </li>
#          <li class="MobileFilters-listItem">
#           <a class="MobileFilters-listItemLink" data-testid="filter-button" href="/search?q=sql&amp;l=los+angeles%2C+ca&amp;fdb=14&amp;from=serptopfilter&amp;pp=" rel="nofollow">
#            14 days
#           </a>
#          </li>
#          <li class="MobileFilters-listItem">
#           <a class="MobileFilters-listItemLink" data-testid="filter-button" href="/search?q=sql&amp;l=los+angeles%2C+ca&amp;fdb=30&amp;from=serptopfilter&amp;pp=" rel="nofollow">
#            30 days
#           </a>
#          </li>
#         </ul>
#        </div>
#        <div class="MobileFilters-group MobileFilters-group-distance" data-testid="distance-filter-group">
#         <p class="MobileFilters-label fl-distance" id="MobDistance">
#          Distance
#         </p>
#         <ul aria-labelledby="MobDistance" class="MobileFilters-list js-filter-menu">
#          <li class="MobileFilters-listItem">
#           <a class="MobileFilters-listItemLink" data-testid="filter-button" href="/search?q=sql&amp;l=los+angeles%2C+ca&amp;mi=exact&amp;from=serptopfilter&amp;pp=" rel="nofollow">
#            Exact location
# ...
#          </li>
#          <li class="next-pagination">
#           <a aria-label="Next page" class="Pagination-link next-pagination" href="/search?q=sql&amp;l=Los+Angeles%2C+CA&amp;pn=2&amp;from=pagination&amp;pp=gQALAAAAAAAAAAAAAAABz721mQAkAQEBBhqXgseCaVJu896uYOfVJGFaOE8rK%2BdBicfJfvbZDIsQAAA%3D" rel="nofollow">
#            <i class="fas fa-angle-right">
#            </i>
#           </a>
#          </li>
#         </ul>
#        </nav>
#        <aside aria-label="I want to receive the latest job alert for Sql in Los Angeles, CA" class="bottom-ja JobAlertForm">
#         <div class="email-alert-container">
#          <div class="email-alert-description">
#           <div class="JobAlertForm-header">
#            <div class="JobAlertForm-toggleText">
#             <h3 class="email-alert-title">
#              <span>
#               I want to receive the latest job alert for Sql in Los Angeles, CA
#              </span>
#              <br/>
#             </h3>
#             <span class="email-alert-text email-msg-placeholder">
#              Use Facebook or Google to register on SimplyHired and create job alert
#             </span>
#            </div>
#           </div>
#          </div>
#          <div class="JobAlertForm-loginWithOneClickSignUp">
#           <button class="btn btn-facebook js-login-facebook" type="button">
#            <span>
#             Continue with Facebook
#            </span>
#           </button>
#           <button class="btn btn-google js-login-google" type="button">
#            <span>
#             Continue with Google
#            </span>
#           </button>
#          </div>
#          <p class="login-disclaimer">
#           By signing in to your account, you agree to SimplyHired's
#           <a href="/about/terms-of-service">
#            Terms of Service
#           </a>
#           and consent to our
#           <a class="modal-dialog-last-focus" href="https://hrtechprivacy.com/brands/simplyhired#privacypolicy">
#            Cookie and Privacy Policy
#           </a>
#           .
#          </p>
#         </div>
#        </aside>
#       </div>
#      </div>
#     </div>
#    </div>
#   </main>
#   <div aria-hidden="true" class="SponsoredJobsDisclaimerModal modal fade" data-keyboard="true" id="sponsored-jobs-disclaimer-modal" role="dialog" tabindex="-1">
#    <div class="SponsoredJobsDisclaimerModal-dialog modal-dialog">
#     <div class="SponsoredJobsDisclaimerModal-content modal-content">
#      <div class="SponsoredJobsDisclaimerModal-header modal-header">
#       <button aria-label="Close" class="close" data-dismiss="modal" type="button">
#        <span aria-hidden="true">
#         ×
#        </span>
#       </button>
#      </div>
#      <div class="SponsoredJobsDisclaimerModal-body modal-body">
#       Displayed here are Job Ads that match your query. SimplyHired may be compensated by these employers, helping keep SimplyHired free for jobseekers. SimplyHired ranks Job Ads based on a combination of employer bids and relevance, such as your search terms and other activity on SimplyHired. For more information, see the
#       <a href="https://hrtechprivacy.com/brands/simplyhired#privacypolicy" target="_blank">
#        SimplyHired Privacy Policy
#       </a>
#       .
#      </div>
#     </div>
#    </div>
#   </div>
#   <div class="Footer-marginTop">
#    <footer class="Footer">
#     <button aria-controls="Footer-links" aria-expanded="false" class="Footer-linksToggleButton hidden-md-up" data-target="#Footer-links" data-toggle="collapse" type="button">
#      Resources and Tools
#      <i class="fas fa-angle-down">
#      </i>
#     </button>
#     <div class="Footer-links collapse" id="Footer-links" itemscope="" itemtype="http://schema.org/Organization">
#      <div class="Footer-section">
#       <h3 class="Footer-listTitle">
#        Jobseeker Tools
#       </h3>
#       <ul class="Footer-listLinks">
#        <li>
#         <a class="Footer-link" href="/resumebuilder" target="_blank">
#          Resume Builder
#         </a>
#        </li>
#        <li>
#         <a class="Footer-link" href="/salaries">
#          Salary Estimator
#         </a>
#        </li>
#        <li>
#         <a class="Footer-link" href="/company">
#          Company Reviews
#         </a>
#        </li>
#       </ul>
#       <div class="Footer-internationalDropdown dropup hidden-sm-down" data-testid="country-selector-SH">
#        <button aria-expanded="false" aria-haspopup="true" aria-label="Country selector: United States, select to change your country" class="Footer-internationalDropdownButton" data-toggle="dropdown" type="button">
#         <span>
#          United States
#         </span>
#         <i class="fas fa-angle-down">
#         </i>
#        </button>
#        <div class="dropdown-menu international-dropdown-wrapper">
#         <div class="Footer-internationalDropdownList">
#          <a class="current-country dropdown-item" href="https://www.simplyhired.com" rel="nofollow">
#           United States
#          </a>
#          <a class="dropdown-item" href="https://www.simplyhired.ca" rel="nofollow">
#           Canada
#          </a>
#          <div class="dropdown-divider">
#          </div>
#          <a class="dropdown-item" href="https://www.simplyhired.com.ar" rel="nofollow">
#           Argentina
#          </a>
#          <a class="dropdown-item" href="https://www.simplyhired.com.au" rel="nofollow">
#           Australia
#          </a>
#          <a class="dropdown-item" href="https://www.simplyhired.be" rel="nofollow">
#           België
#          </a>
#          <a class="dropdown-item" href="https://www.simplyhired.com.br" rel="nofollow">
#           Brasil
#          </a>
#          <a class="dropdown-item" href="https://www.simplyhired.de" rel="nofollow">
#           Deutschland
#          </a>
#          <a class="dropdown-item" href="https://www.simplyhired.es" rel="nofollow">
#           España
#          </a>
#          <a class="dropdown-item" href="https://www.simplyhired.fr" rel="nofollow">
#           France
#          </a>
#          <a class="dropdown-item" href="https://www.simplyhired.co.in" rel="nofollow">
#           India
#          </a>
#          <a class="dropdown-item" href="https://www.simplyhired.ie" rel="nofollow">
#           Ireland
#          </a>
#          <a class="dropdown-item" href="https://www.simplyhired.it" rel="nofollow">
#           Italia
#          </a>
#          <a class="dropdown-item" href="https://www.simplyhired.mx" rel="nofollow">
#           México
#          </a>
#          <a class="dropdown-item" href="https://www.simplyhired.nl" rel="nofollow">
#           Nederland
#          </a>
#          <a class="dropdown-item" href="https://www.simplyhired.at" rel="nofollow">
#           Österreich
#          </a>
#          <a class="dropdown-item" href="https://www.simplyhired.pt" rel="nofollow">
#           Portugal
#          </a>
#          <a class="dropdown-item" href="https://www.simplyhired.ch" rel="nofollow">
#           Schweiz
#          </a>
#          <a class="dropdown-item" href="https://za.simplyhired.com" rel="nofollow">
#           South Africa
#          </a>
#          <a class="dropdown-item" href="https://www.simplyhired.se" rel="nofollow">
#           Sverige
#          </a>
#          <a class="dropdown-item" href="https://www.simplyhired.co.uk" rel="nofollow">
#           United Kingdom
#          </a>
#          <a class="dropdown-item" href="https://www.simplyhired.kr" rel="nofollow">
#           한국
#          </a>
#          <a class="dropdown-item" href="https://www.simplyhired.cn" rel="nofollow">
#           中国
#          </a>
#          <a class="dropdown-item" href="https://www.simplyhired.jp" rel="nofollow">
#           日本
#          </a>
#         </div>
#        </div>
#       </div>
#      </div>
#      <div class="Footer-section">
#       <h3 class="Footer-listTitle">
#        Employer Tools
#       </h3>
#       <ul class="Footer-listLinks">
#        <li>
#         <a class="Footer-link" href="/post-jobs">
#          Post Jobs
#         </a>
#        </li>
#        <li>
#         <a class="Footer-link" href="/hris">
#          HRIS
#         </a>
#        </li>
#        <li>
#         <a class="Footer-link" href="/hr-tools/onboarding">
#          Onboarding
#         </a>
#        </li>
#        <li>
#         <a class="Footer-link" href="/hr-tools/documents">
#          Documents
#         </a>
#        </li>
#        <li>
#         <a class="Footer-link" href="/hr-tools/time-off">
#          Time Off Tracker
#         </a>
#        </li>
#        <li>
#         <a class="Footer-link" href="/hr-tools/benefits">
#          Benefits Tracker
#         </a>
#        </li>
#        <li>
#         <a class="Footer-link" href="/hr-tools/org-chart">
#          Org Chart
#         </a>
#        </li>
#        <li>
#         <a class="Footer-link" href="/hr-tools/attendance">
#          Attendance Tracker
#         </a>
#        </li>
#       </ul>
#      </div>
#      <div class="Footer-section">
#       <h3 class="Footer-listTitle">
#        Jobseeker Resources
#       </h3>
#       <ul class="Footer-listLinks">
#        <li>
#         <a class="Footer-link" href="/search/advice">
#          Career Advice Home
#         </a>
#        </li>
#        <li>
#         <a class="Footer-link" href="/search/advice/interview-questions">
#          Example Interview Questions
#         </a>
#        </li>
#        <li>
#         <a class="Footer-link" href="/search/advice/resume-samples">
#          Resume Samples
#         </a>
#        </li>
#        <li>
#         <a class="Footer-link" href="/search/advice/jobs-that-pay-well">
#          Jobs That Pay Well
#         </a>
#        </li>
#       </ul>
#      </div>
#      <div class="Footer-section">
#       <h3 class="Footer-listTitle">
#        Employer Resources
#       </h3>
#       <ul class="Footer-listLinks">
#        <li>
#         <a class="Footer-link" href="/post-jobs">
#          Employer Advice Home
#         </a>
#        </li>
#        <li>
#         <a class="Footer-link" href="/post-jobs/how-to-hire">
#          How to Hire
#         </a>
#        </li>
#       </ul>
#      </div>
#      <div class="Footer-section">
#       <h3 class="Footer-listTitle">
#        Browse
#       </h3>
#       <ul class="Footer-listLinks">
#        <li>
#         <a class="Footer-link" href="/browse-jobs/titles">
#          All Jobs
#         </a>
#        </li>
#        <li>
#         <a class="Footer-link" href="/browse-jobs/salaries">
#          All Salaries
#         </a>
#        </li>
#        <li>
#         <a class="Footer-link" href="/browse-jobs/cities">
#          All Cities
#         </a>
#        </li>
#        <li>
#         <a class="Footer-link" href="/browse-jobs/companies">
#          All Companies
#         </a>
#        </li>
#       </ul>
#      </div>
#      <div class="Footer-section">
#       <h3 class="Footer-listTitle">
#        Stay Connected
#       </h3>
#       <ul class="Footer-listLinks">
#        <li>
#         <a class="Footer-link" href="/about/contact-us">
#          Contact Us
#         </a>
#        </li>
#        <li>
#         <a class="Footer-link" href="/blog/">
#          SimplyHired Blog
#         </a>
#        </li>
#       </ul>
#      </div>
#     </div>
#     <div class="Footer-base">
#      <a aria-label="Find Jobs and Careers - SimplyHired.com Job Search" class="Footer-logoLink" href="/" itemprop="url">
#       <img alt="Find Jobs and Careers - SimplyHired.com Job Search" class="footer-logo" height="30" itemprop="logo" src="https://d3iouj7udfksni.cloudfront.net/static/logos/SH_Horizontal_Wordmark.svg" width="182"/>
#      </a>
#      <div class="Footer-internationalDropdown dropup hidden-md-up" data-testid="country-selector-SH">
#       <button aria-expanded="false" aria-haspopup="true" aria-label="Country selector: United States, select to change your country" class="Footer-internationalDropdownButton" data-toggle="dropdown" type="button">
#        <span>
#         United States
#        </span>
#        <i class="fas fa-angle-down">
#        </i>
#       </button>
#       <div class="dropdown-menu international-dropdown-wrapper">
#        <div class="Footer-internationalDropdownList">
#         <a class="current-country dropdown-item" href="https://www.simplyhired.com" rel="nofollow">
#          United States
#         </a>
#         <a class="dropdown-item" href="https://www.simplyhired.ca" rel="nofollow">
#          Canada
#         </a>
#         <div class="dropdown-divider">
#         </div>
#         <a class="dropdown-item" href="https://www.simplyhired.com.ar" rel="nofollow">
#          Argentina
#         </a>
#         <a class="dropdown-item" href="https://www.simplyhired.com.au" rel="nofollow">
#          Australia
#         </a>
#         <a class="dropdown-item" href="https://www.simplyhired.be" rel="nofollow">
#          België
#         </a>
#         <a class="dropdown-item" href="https://www.simplyhired.com.br" rel="nofollow">
#          Brasil
#         </a>
#         <a class="dropdown-item" href="https://www.simplyhired.de" rel="nofollow">
#          Deutschland
#         </a>
#         <a class="dropdown-item" href="https://www.simplyhired.es" rel="nofollow">
#          España
#         </a>
#         <a class="dropdown-item" href="https://www.simplyhired.fr" rel="nofollow">
#          France
#         </a>
#         <a class="dropdown-item" href="https://www.simplyhired.co.in" rel="nofollow">
#          India
#         </a>
#         <a class="dropdown-item" href="https://www.simplyhired.ie" rel="nofollow">
#          Ireland
#         </a>
#         <a class="dropdown-item" href="https://www.simplyhired.it" rel="nofollow">
#          Italia
#         </a>
#         <a class="dropdown-item" href="https://www.simplyhired.mx" rel="nofollow">
#          México
#         </a>
#         <a class="dropdown-item" href="https://www.simplyhired.nl" rel="nofollow">
#          Nederland
#         </a>
#         <a class="dropdown-item" href="https://www.simplyhired.at" rel="nofollow">
#          Österreich
#         </a>
#         <a class="dropdown-item" href="https://www.simplyhired.pt" rel="nofollow">
#          Portugal
#         </a>
#         <a class="dropdown-item" href="https://www.simplyhired.ch" rel="nofollow">
#          Schweiz
#         </a>
#         <a class="dropdown-item" href="https://za.simplyhired.com" rel="nofollow">
#          South Africa
#         </a>
#         <a class="dropdown-item" href="https://www.simplyhired.se" rel="nofollow">
#          Sverige
#         </a>
#         <a class="dropdown-item" href="https://www.simplyhired.co.uk" rel="nofollow">
#          United Kingdom
#         </a>
#         <a class="dropdown-item" href="https://www.simplyhired.kr" rel="nofollow">
#          한국
#         </a>
#         <a class="dropdown-item" href="https://www.simplyhired.cn" rel="nofollow">
#          中国
#         </a>
#         <a class="dropdown-item" href="https://www.simplyhired.jp" rel="nofollow">
#          日本
#         </a>
#        </div>
#       </div>
#      </div>
#      <p class="Footer-appLinksHeader hidden-md-up">
#       Take your job search wherever you go.
#      </p>
#      <ul class="Footer-appLinks" data-testid="native-app-download-links">
#       <li>
#        <a aria-label="Download SimplyHired on the Apple App Store" class="Footer-appleAppStoreButton js-gtm" data-event-action="Mobile Applications" href="https://itunes.apple.com/us/app/job-search-simply-hired/id730634951?mt=8&amp;uo=4" rel="noopener noreferrer" target="_blank">
#        </a>
#       </li>
#       <li>
#        <a aria-label="Get SimplyHired on Google Play" class="Footer-googlePlayStoreButton js-gtm" data-event-action="Mobile Applications" href="https://play.google.com/store/apps/details?id=com.simplyhired.android.jobsearch" rel="noopener noreferrer" target="_blank">
#        </a>
#       </li>
#      </ul>
#      <div class="Footer-baseLinks">
#       <span class="Footer-copyright">
#        © 2022 SH Inc.
#       </span>
#       <a class="Footer-baseLink" href="https://hrtechprivacy.com/brands/simplyhired#privacypolicy" rel="nofollow">
#        Privacy
#       </a>
#       |
#       <a class="Footer-baseLink" href="/about/terms-of-service" rel="nofollow">
#        Terms
#       </a>
#       |
#       <a class="Footer-baseLink" href="https://hrtechprivacy.com/" rel="nofollow">
#        Privacy Center
#       </a>
#       |
#       <a class="Footer-baseLink" href="/accessibility" rel="nofollow">
#        Accessibility
#       </a>
#       |
#       <a class="Footer-baseLink" href="/about/ccpa" rel="nofollow">
#        Do Not Sell My Personal Information
#       </a>
#      </div>
#     </div>
#    </footer>
#   </div>
#  </body>
# </html>

# %% [markdown]
# Open the URL in Chrome. Inspect the elements to find a pattern between the jobs.
#
# Identify the tag, attribute, and attribute value for the outermost portion of each job.
#
# Do a findAll to assign a list of jobs to a variable.

# %%
job_box = new_page.findAll('div',attrs={'class':'SerpJob-jobCard card'})

# %% [markdown]
# Print out the variable containing the list of jobs

# %%
job_box
# Out:
# [<div class="SerpJob-jobCard card" data-jobkey="c0qDvt82XR-JgOFHDNoiJTqfmZuOqciYZbjC-zGGR_VnZ62ulqXC8w"><div class="jobposting-title-container"><h3 class="jobposting-title"><a aria-label="Full description: Content Policy Analyst, Nudity &amp; Sexual Activity" class="SerpJob-link card-link" data-mdref="/job/c0qDvt82XR-JgOFHDNoiJTqfmZuOqciYZbjC-zGGR_VnZ62ulqXC8w?tk=1g0asvil5hbh8800&amp;tkt=serp&amp;isp=0&amp;q=sql" href="/job/c0qDvt82XR-JgOFHDNoiJTqfmZuOqciYZbjC-zGGR_VnZ62ulqXC8w?q=sql" rel="nofollow" target="_blank">Content Policy Analyst, Nudity &amp; Sexual Activity</a></h3><div class="btn-savejobs-withtext"><button aria-expanded="false" aria-label="Save job" class="btn btn-savejobs-withtext btn-savejobs" title="Save job" type="button"><i aria-hidden="true" class="heart-placeholder fa-fw"></i></button></div></div><div class="jobposting-subtitle"><span class="JobPosting-labelWithIcon jobposting-company">TikTok</span><span class="jobposting-dash"> - </span><span class="JobPosting-labelWithIcon jobposting-location"><span><span class="jobposting-location">Los Angeles, CA</span></span> </span><span class="CompanyRatings-serp"><span class="CompanyRatings-ratingDigit">3.3</span><span><span class="CompanyRatings-star"><i aria-hidden="true" class="fas fa-star"></i></span></span></span></div><div class="SerpJob-snippetContainer"><p class="jobposting-snippet">You will need a deep understanding of the platform and how it can be abused while championing body positivity/body diversity and ensuring policies protect users…</p></div><div class="SerpJob-metaInfo"><div class="SerpJob-metaInfoLeft"><div class="jobposting-salary SerpJob-salary SerpJob-salary--is-estimate">Estimated: <!-- -->$59,000 - $81,000 a year<div style="display:inline"><span><button class="salary-disclaimer disclaimer-button" type="button"><i class="fas fa-info-circle"></i></button></span></div></div></div><div class="SerpJob-metaInfoRight"><span class="SerpJob-timestamp"><time datetime="2021-12-19T08:31:47Z"></time></span></div></div></div>,
#  <div class="SerpJob-jobCard card" data-jobkey="nBBHkUk8690ib3DdCfCxM04mrBvUSQ8yG1M8jCXjQQcbf8E5slyK6Q"><div class="jobposting-title-container"><h3 class="jobposting-title"><a aria-label="Full description: Junior Data Analyst - Entry Level" class="SerpJob-link card-link" data-mdref="/job/nBBHkUk8690ib3DdCfCxM04mrBvUSQ8yG1M8jCXjQQcbf8E5slyK6Q?tk=1g0asvil5hbh8800&amp;tkt=serp&amp;isp=0&amp;q=sql" href="/job/nBBHkUk8690ib3DdCfCxM04mrBvUSQ8yG1M8jCXjQQcbf8E5slyK6Q?q=sql" rel="nofollow" target="_blank">Junior Data Analyst - Entry Level</a></h3><div class="btn-savejobs-withtext"><button aria-expanded="false" aria-label="Save job" class="btn btn-savejobs-withtext btn-savejobs" title="Save job" type="button"><i aria-hidden="true" class="heart-placeholder fa-fw"></i></button></div></div><div class="jobposting-subtitle"><span class="JobPosting-labelWithIcon jobposting-company">PCS GLOBAL TECH</span><span class="jobposting-dash"> - </span><span class="JobPosting-labelWithIcon jobposting-location"><span><span class="jobposting-location">Los Angeles, CA</span></span> </span></div><div class="SerpJob-snippetContainer"><p class="jobposting-snippet">Microsoft SQL Server, Business Intelligence (BI), Azure, Compliance, Analytics, Predictive Analytics,Data Mining and Analysis, Dashboards and Reporting, Mobile…</p></div><div class="SerpJob-metaInfo"><div class="SerpJob-metaInfoLeft"><div class="jobposting-salary SerpJob-salary">$60,000 - $70,000 a year</div><div class="SerpJob-simplyApplyLabel">Quick Apply</div></div><div class="SerpJob-metaInfoRight"><span class="SerpJob-timestamp"><time datetime="2022-04-04T15:06:01Z">6d</time></span></div></div></div>,
#  <div class="SerpJob-jobCard card" data-jobkey="Ml1U9ooP0ukF0SjpoWxhhfengV4L7uNH3KtiK7HvDxDjhQ2eSqVTfg"><div class="jobposting-title-container"><h3 class="jobposting-title"><a aria-label="Full description: Threat Researcher" class="SerpJob-link card-link" data-mdref="/job/Ml1U9ooP0ukF0SjpoWxhhfengV4L7uNH3KtiK7HvDxDjhQ2eSqVTfg?tk=1g0asvil5hbh8800&amp;tkt=serp&amp;isp=0&amp;q=sql" href="/job/Ml1U9ooP0ukF0SjpoWxhhfengV4L7uNH3KtiK7HvDxDjhQ2eSqVTfg?q=sql" rel="nofollow" target="_blank">Threat Researcher</a></h3><div class="btn-savejobs-withtext"><button aria-expanded="false" aria-label="Save job" class="btn btn-savejobs-withtext btn-savejobs" title="Save job" type="button"><i aria-hidden="true" class="heart-placeholder fa-fw"></i></button></div></div><div class="jobposting-subtitle"><span class="JobPosting-labelWithIcon jobposting-company">TikTok</span><span class="jobposting-dash"> - </span><span class="JobPosting-labelWithIcon jobposting-location"><span><span class="jobposting-location">Los Angeles, CA</span></span> </span><span class="CompanyRatings-serp"><span class="CompanyRatings-ratingDigit">3.3</span><span><span class="CompanyRatings-star"><i aria-hidden="true" class="fas fa-star"></i></span></span></span></div><div class="SerpJob-snippetContainer"><p class="jobposting-snippet">We are seeking an experience quantitative or mixed-methods researcher with subject matter expertise in multiple areas, including: Violent Extremism …</p></div><div class="SerpJob-metaInfo"><div class="SerpJob-metaInfoLeft"><div class="jobposting-salary SerpJob-salary SerpJob-salary--is-estimate">Estimated: <!-- -->$70,000 - $95,000 a year<div style="display:inline"><span><button class="salary-disclaimer disclaimer-button" type="button"><i class="fas fa-info-circle"></i></button></span></div></div></div><div class="SerpJob-metaInfoRight"><span class="SerpJob-timestamp"><time datetime="2021-12-13T09:25:04Z"></time></span></div></div></div>,
#  <div class="SerpJob-jobCard card" data-jobkey="0UG0y6SnuhgX-P3ex68IM1juHng0f9V3AB9vbypQVwhbtUocL2s8fA"><div class="jobposting-title-container"><h3 class="jobposting-title"><a aria-label="Full description: Data Analysis and Visualization Specialist" class="SerpJob-link card-link" data-mdref="/job/0UG0y6SnuhgX-P3ex68IM1juHng0f9V3AB9vbypQVwhbtUocL2s8fA?tk=1g0asvil5hbh8800&amp;tkt=serp&amp;isp=0&amp;q=sql" href="/job/0UG0y6SnuhgX-P3ex68IM1juHng0f9V3AB9vbypQVwhbtUocL2s8fA?q=sql" rel="nofollow" target="_blank">Data Analysis and Visualization Specialist</a></h3><div class="btn-savejobs-withtext"><button aria-expanded="false" aria-label="Save job" class="btn btn-savejobs-withtext btn-savejobs" title="Save job" type="button"><i aria-hidden="true" class="heart-placeholder fa-fw"></i></button></div></div><div class="jobposting-subtitle"><span class="JobPosting-labelWithIcon jobposting-company">TikTok</span><span class="jobposting-dash"> - </span><span class="JobPosting-labelWithIcon jobposting-location"><span><span class="jobposting-location">Los Angeles, CA</span></span> </span><span class="CompanyRatings-serp"><span class="CompanyRatings-ratingDigit">3.3</span><span><span class="CompanyRatings-star"><i aria-hidden="true" class="fas fa-star"></i></span></span></span></div><div class="SerpJob-snippetContainer"><p class="jobposting-snippet">You will build data visuals and provide key data insights to cross-functional partners in moments of crises and work on some of the highest priority safety…</p></div><div class="SerpJob-metaInfo"><div class="SerpJob-metaInfoLeft"><div class="jobposting-salary SerpJob-salary SerpJob-salary--is-estimate">Estimated: <!-- -->$63,000 - $83,000 a year<div style="display:inline"><span><button class="salary-disclaimer disclaimer-button" type="button"><i class="fas fa-info-circle"></i></button></span></div></div></div><div class="SerpJob-metaInfoRight"><span class="SerpJob-timestamp"><time datetime="2021-11-17T03:14:12Z"></time></span></div></div></div>,
#  <div class="SerpJob-jobCard card" data-jobkey="TCMa73PxLux2JGp4CChojOBoyG3vxkRQQkDhLPA2zLvR1MDt9dqAVQ"><div class="jobposting-title-container"><h3 class="jobposting-title"><a aria-label="Full description: Software Development Engineer II" class="SerpJob-link card-link" data-mdref="/job/TCMa73PxLux2JGp4CChojOBoyG3vxkRQQkDhLPA2zLvR1MDt9dqAVQ?tk=1g0asvil5hbh8800&amp;tkt=serp&amp;isp=0&amp;q=sql" href="/job/TCMa73PxLux2JGp4CChojOBoyG3vxkRQQkDhLPA2zLvR1MDt9dqAVQ?q=sql" rel="nofollow" target="_blank">Software Development Engineer II</a></h3><div class="btn-savejobs-withtext"><button aria-expanded="false" aria-label="Save job" class="btn btn-savejobs-withtext btn-savejobs" title="Save job" type="button"><i aria-hidden="true" class="heart-placeholder fa-fw"></i></button></div></div><div class="jobposting-subtitle"><span class="JobPosting-labelWithIcon jobposting-company"><a class="card-link" href="/company/Amazon.com" target="_blank">Amazon.com</a></span><span class="jobposting-dash"> - </span><span class="JobPosting-labelWithIcon jobposting-location"><span><span class="jobposting-location">Santa Monica, CA</span></span> <a class="more-location-link" href="/search?q=sql&amp;l=los+angeles%2C+ca&amp;dupe=H2QWCvc7eW0pZCL82i2VRKqtpmrQkmoctPnOuBEeBrvFPzcNlQa1nrbUzeKtXw&amp;pp=" rel="nofollow">+2 locations</a></span><span class="CompanyRatings-serp"><span class="CompanyRatings-ratingDigit">3.5</span><span><span class="CompanyRatings-star"><i aria-hidden="true" class="fas fa-star"></i></span></span></span></div><div class="SerpJob-snippetContainer"><p class="jobposting-snippet">We build and ultiize services and applications using AWS and other cutting edge technologies while providing full visibility into the transactions using static…</p></div><div class="SerpJob-metaInfo"><div class="SerpJob-metaInfoLeft"><div class="jobposting-salary SerpJob-salary">$102,664 - $187,618 a year</div><div class="SerpJob-simplyApplyLabel">Quick Apply</div></div><div class="SerpJob-metaInfoRight"><span class="SerpJob-timestamp"><time datetime="2022-03-25T00:34:06Z"></time></span></div></div></div>,
#  <div class="SerpJob-jobCard card" data-jobkey="GjfRsfyeE9v2QiJYbaWoknu-G5Po-BiBqQqLq3IA2RKwaT2UaZN7ig"><div class="jobposting-title-container"><h3 class="jobposting-title"><a aria-label="Full description: Threat Analyst, Network Analysis and Targeted Manipulation" class="SerpJob-link card-link" data-mdref="/job/GjfRsfyeE9v2QiJYbaWoknu-G5Po-BiBqQqLq3IA2RKwaT2UaZN7ig?tk=1g0asvil5hbh8800&amp;tkt=serp&amp;isp=0&amp;q=sql" href="/job/GjfRsfyeE9v2QiJYbaWoknu-G5Po-BiBqQqLq3IA2RKwaT2UaZN7ig?q=sql" rel="nofollow" target="_blank">Threat Analyst, Network Analysis and Targeted Manipulation</a></h3><div class="btn-savejobs-withtext"><button aria-expanded="false" aria-label="Save job" class="btn btn-savejobs-withtext btn-savejobs" title="Save job" type="button"><i aria-hidden="true" class="heart-placeholder fa-fw"></i></button></div></div><div class="jobposting-subtitle"><span class="JobPosting-labelWithIcon jobposting-company">TikTok</span><span class="jobposting-dash"> - </span><span class="JobPosting-labelWithIcon jobposting-location"><span><span class="jobposting-location">Los Angeles, CA</span></span> </span><span class="CompanyRatings-serp"><span class="CompanyRatings-ratingDigit">3.3</span><span><span class="CompanyRatings-star"><i aria-hidden="true" class="fas fa-star"></i></span></span></span></div><div class="SerpJob-snippetContainer"><p class="jobposting-snippet">Using data analysis skills, subject-matter expertise, regional experience, and language skills, a NATM Analyst will have the opportunity to identify and…</p></div><div class="SerpJob-metaInfo"><div class="SerpJob-metaInfoLeft"><div class="jobposting-salary SerpJob-salary SerpJob-salary--is-estimate">Estimated: <!-- -->$92,000 - $130,000 a year<div style="display:inline"><span><button class="salary-disclaimer disclaimer-button" type="button"><i class="fas fa-info-circle"></i></button></span></div></div></div><div class="SerpJob-metaInfoRight"><span class="SerpJob-timestamp"><time datetime="2021-12-01T09:24:22Z"></time></span></div></div></div>,
#  <div class="SerpJob-jobCard card" data-jobkey="vtDw8l2s4F70KeXZwRskADn3PX8_K1Xyl4CaCR9VZqznTeeSYE9-rg"><div class="jobposting-title-container"><h3 class="jobposting-title"><a aria-label="Full description: Data Analyst I" class="SerpJob-link card-link" data-mdref="/job/vtDw8l2s4F70KeXZwRskADn3PX8_K1Xyl4CaCR9VZqznTeeSYE9-rg?tk=1g0asvil5hbh8800&amp;tkt=serp&amp;isp=0&amp;q=sql" href="/job/vtDw8l2s4F70KeXZwRskADn3PX8_K1Xyl4CaCR9VZqznTeeSYE9-rg?q=sql" rel="nofollow" target="_blank">Data Analyst I</a></h3><div class="btn-savejobs-withtext"><button aria-expanded="false" aria-label="Save job" class="btn btn-savejobs-withtext btn-savejobs" title="Save job" type="button"><i aria-hidden="true" class="heart-placeholder fa-fw"></i></button></div></div><div class="jobposting-subtitle"><span class="JobPosting-labelWithIcon jobposting-company">PriceSpider</span><span class="jobposting-dash"> - </span><span class="JobPosting-labelWithIcon jobposting-location"><span><span class="jobposting-location">Los Angeles, CA</span></span> </span></div><div class="SerpJob-snippetContainer"><p class="jobposting-snippet">Information Technology or Data Science Degree, Certification, or related technical field or equivalent practical experience.</p></div><div class="SerpJob-metaInfo"><div class="SerpJob-metaInfoLeft"><div class="jobposting-salary SerpJob-salary SerpJob-salary--is-estimate">Estimated: <!-- -->$72,000 - $96,000 a year<div style="display:inline"><span><button class="salary-disclaimer disclaimer-button" type="button"><i class="fas fa-info-circle"></i></button></span></div></div><div class="SerpJob-simplyApplyLabel">Quick Apply</div></div><div class="SerpJob-metaInfoRight"><span class="SerpJob-timestamp"><time datetime="2022-04-06T23:19:13Z">4d</time></span></div></div></div>,
#  <div class="SerpJob-jobCard card" data-jobkey="XwTsRTID67CpYkupZH0FIzVTctqkcjbLlfeCn0aPn4XZ9XHV4osshQ"><div class="jobposting-title-container"><h3 class="jobposting-title"><a aria-label="Full description: Python Developer with Django, Postgres SQL" class="SerpJob-link card-link" data-mdref="/job/XwTsRTID67CpYkupZH0FIzVTctqkcjbLlfeCn0aPn4XZ9XHV4osshQ?tk=1g0asvil5hbh8800&amp;tkt=serp&amp;isp=0&amp;q=sql" href="/job/XwTsRTID67CpYkupZH0FIzVTctqkcjbLlfeCn0aPn4XZ9XHV4osshQ?q=sql" rel="nofollow" target="_blank">Python Developer with Django, Postgres SQL</a></h3><div class="btn-savejobs-withtext"><button aria-expanded="false" aria-label="Save job" class="btn btn-savejobs-withtext btn-savejobs" title="Save job" type="button"><i aria-hidden="true" class="heart-placeholder fa-fw"></i></button></div></div><div class="jobposting-subtitle"><span class="JobPosting-labelWithIcon jobposting-company">Tech IM inc</span><span class="jobposting-dash"> - </span><span class="JobPosting-labelWithIcon jobposting-location"><span><span class="jobposting-location">Burbank, CA</span></span> </span></div><div class="SerpJob-snippetContainer"><p class="jobposting-snippet">Obsess on developing intuitive applications for the frontend or backend using technologies such as Node.js, Vue, React, Angular, Python, Django, etc.</p></div><div class="SerpJob-metaInfo"><div class="SerpJob-metaInfoLeft"><div class="jobposting-salary SerpJob-salary">$74,885 - $168,999 a year</div><div class="SerpJob-simplyApplyLabel">Quick Apply</div></div><div class="SerpJob-metaInfoRight"><span class="SerpJob-timestamp"><time datetime="2022-03-22T15:10:44Z"></time></span></div></div></div>,
#  <div class="SerpJob-jobCard card" data-jobkey="xuxbHl9tPF17aZ3YWhSCGmnDt49mr_0zxFHMNqVkYxAC0GrWLU2jOA"><div class="jobposting-title-container"><h3 class="jobposting-title"><a aria-label="Full description: Data Analyst" class="SerpJob-link card-link" data-mdref="/job/xuxbHl9tPF17aZ3YWhSCGmnDt49mr_0zxFHMNqVkYxAC0GrWLU2jOA?tk=1g0asvil5hbh8800&amp;tkt=serp&amp;isp=0&amp;q=sql" href="/job/xuxbHl9tPF17aZ3YWhSCGmnDt49mr_0zxFHMNqVkYxAC0GrWLU2jOA?q=sql" rel="nofollow" target="_blank">Data Analyst</a></h3><div class="btn-savejobs-withtext"><button aria-expanded="false" aria-label="Save job" class="btn btn-savejobs-withtext btn-savejobs" title="Save job" type="button"><i aria-hidden="true" class="heart-placeholder fa-fw"></i></button></div></div><div class="jobposting-subtitle"><span class="JobPosting-labelWithIcon jobposting-company">FULLER THEOLOGICAL</span><span class="jobposting-dash"> - </span><span class="JobPosting-labelWithIcon jobposting-location"><span><span class="jobposting-location">Pasadena, CA</span></span> </span></div><div class="SerpJob-snippetContainer"><p class="jobposting-snippet">Status: Full-time Non-Exempt. Reports to: Director of Institutional Research, Business Analysis and Implementation. Basic understanding of SQL is desired.</p></div><div class="SerpJob-metaInfo"><div class="SerpJob-metaInfoLeft"><div class="jobposting-salary SerpJob-salary SerpJob-salary--is-estimate">Estimated: <!-- -->$76,000 - $100,000 a year<div style="display:inline"><span><button class="salary-disclaimer disclaimer-button" type="button"><i class="fas fa-info-circle"></i></button></span></div></div><div class="SerpJob-simplyApplyLabel">Quick Apply</div></div><div class="SerpJob-metaInfoRight"><span class="SerpJob-timestamp"><time datetime="2022-03-15T00:09:30Z"></time></span></div></div></div>,
#  <div class="SerpJob-jobCard card" data-jobkey="ydnEsNGA8D80AS0fUCpK14kqd3ozBlGp6qZ8x9haVSojKlb17YcXNA"><div class="jobposting-title-container"><h3 class="jobposting-title"><a aria-label="Full description: TikTok LIVE Data Analyst" class="SerpJob-link card-link" data-mdref="/job/ydnEsNGA8D80AS0fUCpK14kqd3ozBlGp6qZ8x9haVSojKlb17YcXNA?tk=1g0asvil5hbh8800&amp;tkt=serp&amp;isp=0&amp;q=sql" href="/job/ydnEsNGA8D80AS0fUCpK14kqd3ozBlGp6qZ8x9haVSojKlb17YcXNA?q=sql" rel="nofollow" target="_blank">TikTok LIVE Data Analyst</a></h3><div class="btn-savejobs-withtext"><button aria-expanded="false" aria-label="Save job" class="btn btn-savejobs-withtext btn-savejobs" title="Save job" type="button"><i aria-hidden="true" class="heart-placeholder fa-fw"></i></button></div></div><div class="jobposting-subtitle"><span class="JobPosting-labelWithIcon jobposting-company">TikTok</span><span class="jobposting-dash"> - </span><span class="JobPosting-labelWithIcon jobposting-location"><span><span class="jobposting-location">Los Angeles, CA</span></span> </span><span class="CompanyRatings-serp"><span class="CompanyRatings-ratingDigit">3.3</span><span><span class="CompanyRatings-star"><i aria-hidden="true" class="fas fa-star"></i></span></span></span></div><div class="SerpJob-snippetContainer"><p class="jobposting-snippet">As part of the US LIVE Operations Team, the Data Analyst will be responsible for helping the team drive insights and analysis as well as decision making…</p></div><div class="SerpJob-metaInfo"><div class="SerpJob-metaInfoLeft"><div class="jobposting-salary SerpJob-salary SerpJob-salary--is-estimate">Estimated: <!-- -->$81,000 - $100,000 a year<div style="display:inline"><span><button class="salary-disclaimer disclaimer-button" type="button"><i class="fas fa-info-circle"></i></button></span></div></div></div><div class="SerpJob-metaInfoRight"><span class="SerpJob-timestamp"><time datetime="2022-02-22T09:03:47Z"></time></span></div></div></div>,
#  <div class="SerpJob-jobCard card" data-jobkey="LYETgJCDxJF_V8MEEOOplJSW9pFELpqkxqjGa6dxvw-wCTjB4h1awQ"><div class="jobposting-title-container"><h3 class="jobposting-title"><a aria-label="Full description: Business Analyst - Rights Management" class="SerpJob-link card-link" data-mdref="/job/LYETgJCDxJF_V8MEEOOplJSW9pFELpqkxqjGa6dxvw-wCTjB4h1awQ?tk=1g0asvil5hbh8800&amp;tkt=serp&amp;isp=0&amp;q=sql" href="/job/LYETgJCDxJF_V8MEEOOplJSW9pFELpqkxqjGa6dxvw-wCTjB4h1awQ?q=sql" rel="nofollow" target="_blank">Business Analyst - Rights Management</a></h3><div class="btn-savejobs-withtext"><button aria-expanded="false" aria-label="Save job" class="btn btn-savejobs-withtext btn-savejobs" title="Save job" type="button"><i aria-hidden="true" class="heart-placeholder fa-fw"></i></button></div></div><div class="jobposting-subtitle"><span class="JobPosting-labelWithIcon jobposting-company">SRP</span><span class="jobposting-dash"> - </span><span class="JobPosting-labelWithIcon jobposting-location"><span><span class="jobposting-location">Los Angeles, CA</span></span> </span><span class="CompanyRatings-serp"><span class="CompanyRatings-ratingDigit">3.5</span><span><span class="CompanyRatings-star"><i aria-hidden="true" class="fas fa-star"></i></span></span></span></div><div class="SerpJob-snippetContainer"><p class="jobposting-snippet">Be able to develop a thorough understanding of the end user functionality, underlying technology, integrations, data architecture, and configurations of the…</p></div><div class="SerpJob-metaInfo"><div class="SerpJob-metaInfoLeft"><div class="jobposting-salary SerpJob-salary">$75 - $100 an hour</div><div class="SerpJob-simplyApplyLabel">Quick Apply</div></div><div class="SerpJob-metaInfoRight"><span class="SerpJob-timestamp"><time datetime="2022-04-07T16:15:51Z">3d</time></span></div></div></div>]

# %% [markdown]
# - Create a dictionary to hold the job details. Initialize the dictionary values to an empty list for each key.
#
#
# - Loop through the jobs
#     - Scrape for the required job components and assign each to a variable
#     - Append the variable to the appropriate key for the dictionary initialized above
#     - Print out the variable value
#     - To delimit each article, print out a line of repeating non-alphanumeric characters of your choice

# %%
job_parmas = {
    'title': [],
    'company':[],
    'location':[],
    'link':[]
}

# %% [markdown]
# Print out the contents of the job details dictionary

# %%
for job in job_box:
    
    job_parmas['title'].append(job.find('h3', attrs={'class': 'jobposting-title'}).text)
    job_parmas['company'].append(job.find('span', attrs={'class': 'JobPosting-labelWithIcon jobposting-company'}).text)
    job_parmas['location'].append(job.find('span', attrs={'class': 'jobposting-location'}).text.strip())
    job_parmas['link'].append(job.find('a')['href'])

# %% [markdown]
# Assign the job details dictionary to a dataframe

# %%
job_parmas
# Out:
# {'title': ['Content Policy Analyst, Nudity & Sexual Activity',
#   'Junior Data Analyst - Entry Level',
#   'Threat Researcher',
#   'Data Analysis and Visualization Specialist',
#   'Software Development Engineer II',
#   'Threat Analyst, Network Analysis and Targeted Manipulation',
#   'Data Analyst I',
#   'Python Developer with Django, Postgres SQL',
#   'Data Analyst',
#   'TikTok LIVE Data Analyst',
#   'Business Analyst - Rights Management'],
#  'company': ['TikTok',
#   'PCS GLOBAL TECH',
#   'TikTok',
#   'TikTok',
#   'Amazon.com',
#   'TikTok',
#   'PriceSpider',
#   'Tech IM inc',
#   'FULLER THEOLOGICAL',
#   'TikTok',
#   'SRP'],
#  'location': ['Los Angeles, CA',
#   'Los Angeles, CA',
#   'Los Angeles, CA',
#   'Los Angeles, CA',
#   'Santa Monica, CA\xa0+2 locations',
#   'Los Angeles, CA',
#   'Los Angeles, CA',
#   'Burbank, CA',
#   'Pasadena, CA',
#   'Los Angeles, CA',
#   'Los Angeles, CA'],
#  'link': ['/job/c0qDvt82XR-JgOFHDNoiJTqfmZuOqciYZbjC-zGGR_VnZ62ulqXC8w?q=sql',
#   '/job/nBBHkUk8690ib3DdCfCxM04mrBvUSQ8yG1M8jCXjQQcbf8E5slyK6Q?q=sql',
#   '/job/Ml1U9ooP0ukF0SjpoWxhhfengV4L7uNH3KtiK7HvDxDjhQ2eSqVTfg?q=sql',
#   '/job/0UG0y6SnuhgX-P3ex68IM1juHng0f9V3AB9vbypQVwhbtUocL2s8fA?q=sql',
#   '/job/TCMa73PxLux2JGp4CChojOBoyG3vxkRQQkDhLPA2zLvR1MDt9dqAVQ?q=sql',
#   '/job/GjfRsfyeE9v2QiJYbaWoknu-G5Po-BiBqQqLq3IA2RKwaT2UaZN7ig?q=sql',
#   '/job/vtDw8l2s4F70KeXZwRskADn3PX8_K1Xyl4CaCR9VZqznTeeSYE9-rg?q=sql',
#   '/job/XwTsRTID67CpYkupZH0FIzVTctqkcjbLlfeCn0aPn4XZ9XHV4osshQ?q=sql',
#   '/job/xuxbHl9tPF17aZ3YWhSCGmnDt49mr_0zxFHMNqVkYxAC0GrWLU2jOA?q=sql',
#   '/job/ydnEsNGA8D80AS0fUCpK14kqd3ozBlGp6qZ8x9haVSojKlb17YcXNA?q=sql',
#   '/job/LYETgJCDxJF_V8MEEOOplJSW9pFELpqkxqjGa6dxvw-wCTjB4h1awQ?q=sql']}

# %%
df = pd.DataFrame.from_dict(job_parmas,orient='columns')

# %% [markdown]
# Print out the first 5 rows of the dataframe

# %%
df.head()
# Out:
#                                               title          company  \
# 0  Content Policy Analyst, Nudity & Sexual Activity           TikTok
# 1                 Junior Data Analyst - Entry Level  PCS GLOBAL TECH
# 2                                 Threat Researcher           TikTok
# 3        Data Analysis and Visualization Specialist           TikTok
# 4                  Software Development Engineer II       Amazon.com
#
#                         location  \
# 0                Los Angeles, CA
# 1                Los Angeles, CA
# 2                Los Angeles, CA
# 3                Los Angeles, CA
# 4  Santa Monica, CA +2 locations
#
#                                                 link
# 0  /job/c0qDvt82XR-JgOFHDNoiJTqfmZuOqciYZbjC-zGGR...
# 1  /job/nBBHkUk8690ib3DdCfCxM04mrBvUSQ8yG1M8jCXjQ...
# 2  /job/Ml1U9ooP0ukF0SjpoWxhhfengV4L7uNH3KtiK7HvD...
# 3  /job/0UG0y6SnuhgX-P3ex68IM1juHng0f9V3AB9vbypQV...
# 4  /job/TCMa73PxLux2JGp4CChojOBoyG3vxkRQQkDhLPA2z...

# %% [markdown]
# Establish a connection to your assignment_02 database.
#
# Append ?charset=utf8 to the database name to avoide codec errors.

# %%
engine = create_engine('mysql+mysqldb://admin:*****@lmu-dev-01.cfw60gqle7ub.us-east-2.rds.amazonaws.com/*****?charset=utf8')

# %% [markdown]
# Insert the dataframe contents to the simplyhired_job table you previously created.
#
# Ensure your variables in the jobs for loop matches the table's column names.
#
# Set the if_exists argument to append to insert into the table you already created.
#
# Do not insert the dataframe's index column.

# %%
df.to_sql('simplyhired_job',engine,if_exists='append',index=False)

# %% [markdown]
# ### Clear out the simplyhired_job table before proceeding.
# Run the following SQL in your database client:
#
# TRUNCATE TABLE simplyhired_job;

# %% [markdown]
# ### Make 10 requests for the SimplyHired search page to scrape 100+ jobs and save the results to the simplyhired_job table
# A single job search request only returns ~10 jobs. Use the pn parameter to "paginate" through the results.
#
# The range function returns a range of numbers. range(1,12) returns 1-10.
#
# Replace the placeholders denoted by \~ALL_CAPS\~.

# %%
for page in range(1,15):
    print('Page:', page)
    
    url = page_url
    params = {'q':'SQL', 'pn':page}
    
    url_requ = requests.get(page_url,params)
    
    new_page = BeautifulSoup(url_requ.text,'html.parser')

    job_box = new_page.findAll('div',attrs={'class':'SerpJob-jobCard card'})

    job_parmas = {
    'title': [],
    'company':[],
    'location':[],
    'link':[]
}

    for job in job_box:
        
        job_parmas['title'].append(job.find('h3', attrs={'class': 'jobposting-title'}).text)
        job_parmas['company'].append(job.find('span', attrs={'class': 'JobPosting-labelWithIcon jobposting-company'}).text)
        job_parmas['location'].append(job.find('span', attrs={'class': 'jobposting-location'}).text.strip())
        job_parmas['link'].append(job.find('a')['href'])
        
    df = pd.DataFrame(job_parmas)
    
    df.to_sql('simplyhired_job', engine, if_exists='append', index=False)
# Out:
# Page: 1
# Page: 2
# Page: 3
# Page: 4
# Page: 5
# Page: 6
# Page: 7
# Page: 8
# Page: 9
# Page: 10
# Page: 11
# Page: 12
# Page: 13
# Page: 14

# %% [markdown]
# Confirm 100+ jobs were properly inserted into the simplyhired_job table. No need to provide proof. I will be running a SELECT on the table.
